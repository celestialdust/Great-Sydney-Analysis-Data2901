# %% [markdown]
# # TASK 1: Initial data loading and clearning in python and Data importing in PostgreSQL server

# %%
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# %%
from sqlalchemy import create_engine, text
import psycopg2
import psycopg2.extras
import json

# %%
from shapely.geometry import Point, Polygon, MultiPolygon
from geoalchemy2 import Geometry, WKTElement
from shapely.wkt import loads
import geopandas as gpd

# %% [markdown]
# ### The below two functions are used to connect the python with PostgreSQL so that we can access database in SQL server.

# %%
credentials = "Credentials.json"

def pgconnect(credential_filepath, db_schema="public"):
    with open(credential_filepath) as f:
        db_conn_dict = json.load(f)
        host       = db_conn_dict['host']
        db_user    = db_conn_dict['user']
        db_pw      = db_conn_dict['password']
        default_db = db_conn_dict['user']
        port       = db_conn_dict['port']
        try:
            db = create_engine(f'postgresql+psycopg2://{db_user}:{db_pw}@{host}:{port}/{default_db}', echo=False)
            conn = db.connect()
            print('Connected successfully.')
        except Exception as e:
            print("Unable to connect to the database.")
            print(e)
            db, conn = None, None
        return db,conn

def query(conn, sqlcmd, args=None, df=True):
    result = pd.DataFrame() if df else None
    try:
        if df:
            result = pd.read_sql_query(sqlcmd, conn, params=args)
        else:
            result = conn.execute(text(sqlcmd), args).fetchall()
            result = result[0] if len(result) == 1 else result
    except Exception as e:
        print("Error encountered: ", e, sep='\n')
    return result

# %%
db, conn = pgconnect(credentials)
# Out:
# Connected successfully.

# %%
conn.execute(text("""CREATE EXTENSION IF NOT EXISTS postgis;"""))

# %%
query(conn, "select PostGIS_Version()")
# Out:
#                          postgis_version
# 0  3.4 USE_GEOS=1 USE_PROJ=1 USE_STATS=1

# %% [markdown]
# # The below is the SA2 dataset

# %% [markdown]
# The xml file storing the metadata is loaded to have a look.

# %%
with open('SA2_2021_AUST_SHP_GDA2020/SA2_2021_AUST_GDA2020.xml', 'r') as f_SA2:
    data_SA2 = f_SA2.read()
SA2_data = BeautifulSoup(data_SA2, "lxml")
SA2_data
# Out:
# <?xml version="1.0" encoding="UTF-8"?><!-- edited with XMLSpy v2020 rel. 2 sp1 (x64) (http://www.altova.com) by  (Australian Bureau of Statistics) --><!-- UNCLASSIFIED --><!-- Built from ANZLIC MET Template ISO 19139 2009-02-18 --><html><body><gmd:md_metadata xmlns:gco="http://www.isotc211.org/2005/gco" xmlns:gmd="http://www.isotc211.org/2005/gmd" xmlns:gml="http://www.opengis.net/gml" xmlns:gts="http://www.isotc211.org/2005/gts" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemalocation="http://www.isotc211.org/2005/gmd http://www.isotc211.org/2005/gmd/gmd.xsd http://www.opengis.net/gml http://www.isotc211.org/2005/gml/gml.xsd http://www.w3.org/1999/xlink http://www.isotc211.org/2005/xlink/xlinks.xsd">
# <gmd:fileidentifier>
# <gco:characterstring>ABS-ASGS-ED3-SA2-2021-7844</gco:characterstring>
# </gmd:fileidentifier>
# <gmd:language>
# <gco:characterstring>eng</gco:characterstring>
# </gmd:language>
# <gmd:characterset>
# <gmd:md_charactersetcode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#MD_CharacterSetCode" codelistvalue="utf8">utf8</gmd:md_charactersetcode>
# </gmd:characterset>
# <gmd:hierarchylevel>
# <gmd:md_scopecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/GAScopeCodeList.xml#MD_ScopeCode" codelistvalue="dataset">dataset</gmd:md_scopecode>
# </gmd:hierarchylevel>
# <gmd:hierarchylevelname>
# <gco:characterstring>dataset</gco:characterstring>
# </gmd:hierarchylevelname>
# <gmd:contact>
# <gmd:ci_responsibleparty>
# <gmd:individualname gco:nilreason="NA">
# <gco:characterstring>
# </gco:characterstring>
# </gmd:individualname>
# <gmd:organisationname>
# <gco:characterstring>Australian Bureau of Statistics (ABS)</gco:characterstring>
# </gmd:organisationname>
# <gmd:positionname>
# <gco:characterstring>ASGS Manager</gco:characterstring>
# </gmd:positionname>
# <gmd:contactinfo>
# <gmd:ci_contact>
# <gmd:phone>
# <gmd:ci_telephone>
# <gmd:voice>
# <gco:characterstring>1300 135 070</gco:characterstring>
# </gmd:voice>
# </gmd:ci_telephone>
# </gmd:phone>
# <gmd:address>
# <gmd:ci_address>
# <gmd:deliverypoint>
# <gco:characterstring>Locked Bag 10</gco:characterstring>
# </gmd:deliverypoint>
# <gmd:city>
# <gco:characterstring>BELCONNEN</gco:characterstring>
# </gmd:city>
# <gmd:administrativearea>
# <gco:characterstring>ACT</gco:characterstring>
# </gmd:administrativearea>
# <gmd:postalcode>
# <gco:characterstring>2616</gco:characterstring>
# </gmd:postalcode>
# <gmd:country>
# <gco:characterstring>Australia</gco:characterstring>
# </gmd:country>
# <gmd:electronicmailaddress>
# <gco:characterstring>client.services@abs.gov.au</gco:characterstring>
# </gmd:electronicmailaddress>
# </gmd:ci_address>
# </gmd:address>
# </gmd:ci_contact>
# </gmd:contactinfo>
# <gmd:role>
# <gmd:ci_rolecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#CI_RoleCode" codelistvalue="author">author</gmd:ci_rolecode>
# </gmd:role>
# </gmd:ci_responsibleparty>
# </gmd:contact>
# <gmd:datestamp>
# <gco:date>2021-07-20</gco:date>
# </gmd:datestamp>
# <gmd:metadatastandardname>
# <gco:characterstring>ANZLIC Metadata Profile: An Australian/New Zealand Profile of AS/NZS ISO 19115:2005, Geographic information - Metadata</gco:characterstring>
# </gmd:metadatastandardname>
# <gmd:metadatastandardversion>
# <gco:characterstring>1.1</gco:characterstring>
# </gmd:metadatastandardversion>
# <gmd:referencesysteminfo>
# <gmd:md_referencesystem>
# <gmd:referencesystemidentifier>
# <gmd:rs_identifier>
# <gmd:code>
# <gco:characterstring>GDA2020  (7 Parameter GDA94 to GDA2020) </gco:characterstring>
# </gmd:code>
# </gmd:rs_identifier>
# </gmd:referencesystemidentifier>
# </gmd:md_referencesystem>
# </gmd:referencesysteminfo>
# <gmd:identificationinfo>
# <gmd:md_dataidentification>
# <gmd:citation>
# <gmd:ci_citation>
# <gmd:title>
# <gco:characterstring>SA2_2021_AUST_GDA2020</gco:characterstring>
# </gmd:title>
# <gmd:alternatetitle>
# <gco:characterstring>Statistical Area Level 2 2021</gco:characterstring>
# </gmd:alternatetitle>
# <gmd:date>
# <gmd:ci_date>
# <gmd:date>
# <gco:date>2021-07-20</gco:date>
# </gmd:date>
# <gmd:datetype>
# <gmd:ci_datetypecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#CI_DateTypeCode" codelistvalue="publication">publication</gmd:ci_datetypecode>
# </gmd:datetype>
# </gmd:ci_date>
# </gmd:date>
# <gmd:othercitationdetails>
# <gco:characterstring>Australian Statistical Geography Standard (ASGS) Edition https://www.abs.gov.au/statistics/standards/australian-statistical-geography-standard-asgs-edition-3/jul2021-jun2026</gco:characterstring>
# </gmd:othercitationdetails>
# </gmd:ci_citation>
# </gmd:citation>
# <gmd:abstract>
# <gco:characterstring>Statistical Areas Level 2 (SA2) are medium-sized general purpose areas built from whole Statistical Areas Level 1 (SA1). Whole SA2s aggregate to form Statistical Areas Level 3 (SA3) in the ASGS Main Structure.
# Further information about these regions can be found in the following publication: Australian Statistical Geography Standard (ASGS) Edition 3
# https://www.abs.gov.au/statistics/standards/australian-statistical-geography-standard-asgs-edition-3/jul2021-jun2026</gco:characterstring>
# </gmd:abstract>
# <gmd:purpose>
# <gco:characterstring>Statistical Areas Level 2 (SA2) are designed to represent communities that interact socially and economically.
#
# The ASGS is constructed on the principle that it must fulfil user needs for geospatially enabled statistics, while also conforming to general classification principles.
# The ASGS is designed to meet user needs for social, demographic and economic statistics. The regions of the ASGS below the State and Territory level are designed such that they are:
# - useful and relevant for data dissemination
# - flexible for aggregation into larger units
# - useful building blocks for user-defined regions.</gco:characterstring>
# </gmd:purpose>
# <gmd:status>
# <gmd:md_progresscode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#MD_ProgressCode" codelistvalue="completed">completed</gmd:md_progresscode>
# </gmd:status>
# <gmd:pointofcontact>
# <gmd:ci_responsibleparty>
# <gmd:individualname gco:nilreason="NA">
# <gco:characterstring></gco:characterstring>
# </gmd:individualname>
# <gmd:organisationname>
# <gco:characterstring>Australian Bureau of Statistics (ABS)</gco:characterstring>
# </gmd:organisationname>
# <gmd:positionname>
# <gco:characterstring>Customer Assistance Service</gco:characterstring>
# </gmd:positionname>
# <gmd:contactinfo>
# <gmd:ci_contact>
# <gmd:phone>
# <gmd:ci_telephone>
# <gmd:voice>
# <gco:characterstring>1300 135 070</gco:characterstring>
# </gmd:voice>
# <gmd:facsimile gco:nilreason="missing">
# <gco:characterstring></gco:characterstring>
# </gmd:facsimile>
# </gmd:ci_telephone>
# </gmd:phone>
# <gmd:address>
# <gmd:ci_address>
# <gmd:deliverypoint>
# <gco:characterstring>Locked Bag 10</gco:characterstring>
# </gmd:deliverypoint>
# <gmd:city>
# <gco:characterstring>BELCONNEN</gco:characterstring>
# </gmd:city>
# <gmd:administrativearea>
# <gco:characterstring>ACT</gco:characterstring>
# </gmd:administrativearea>
# <gmd:postalcode>
# <gco:characterstring>2616</gco:characterstring>
# </gmd:postalcode>
# <gmd:country>
# <gco:characterstring>Australia</gco:characterstring>
# </gmd:country>
# <gmd:electronicmailaddress>
# <gco:characterstring>client.services@abs.gov.au</gco:characterstring>
# </gmd:electronicmailaddress>
# </gmd:ci_address>
# </gmd:address>
# </gmd:ci_contact>
# </gmd:contactinfo>
# <gmd:role>
# <gmd:ci_rolecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#CI_RoleCode" codelistvalue="pointOfContact">pointOfContact</gmd:ci_rolecode>
# </gmd:role>
# </gmd:ci_responsibleparty>
# </gmd:pointofcontact>
# <gmd:resourcemaintenance>
# <gmd:md_maintenanceinformation>
# <gmd:maintenanceandupdatefrequency>
# <gmd:md_maintenancefrequencycode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#MD_MaintenanceFrequencyCode" codelistvalue="continual">continual</gmd:md_maintenancefrequencycode>
# </gmd:maintenanceandupdatefrequency>
# <gmd:dateofnextupdate>
# <gco:date>2026</gco:date>
# </gmd:dateofnextupdate>
# </gmd:md_maintenanceinformation>
# </gmd:resourcemaintenance>
# <gmd:resourceformat xlink:type="simple">
# <gmd:md_format>
# <gmd:name>
# <gco:characterstring>*.xml</gco:characterstring>
# </gmd:name>
# <gmd:version>
# <gco:characterstring>Unknown</gco:characterstring>
# </gmd:version>
# </gmd:md_format>
# </gmd:resourceformat>
# <gmd:descriptivekeywords>
# <gmd:md_keywords>
# <gmd:keyword>
# <gco:characterstring>Australia</gco:characterstring>
# </gmd:keyword>
# <gmd:type>
# <gmd:md_keywordtypecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#MD_KeywordTypeCode" codelistvalue="theme">theme</gmd:md_keywordtypecode>
# </gmd:type>
# <gmd:thesaurusname>
# <gmd:ci_citation>
# <gmd:title>
# <gco:characterstring>ANZLIC Jurisdictions</gco:characterstring>
# </gmd:title>
# <gmd:date>
# <gmd:ci_date>
# <gmd:date>
# <gco:date>2008-10-29</gco:date>
# </gmd:date>
# <gmd:datetype>
# <gmd:ci_datetypecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#CI_DateTypeCode" codelistvalue="revision">revision</gmd:ci_datetypecode>
# </gmd:datetype>
# </gmd:ci_date>
# </gmd:date>
# <gmd:edition>
# <gco:characterstring>Version 2.1</gco:characterstring>
# </gmd:edition>
# <gmd:editiondate>
# <gco:date>2008-10-29</gco:date>
# </gmd:editiondate>
# <gmd:identifier>
# <gmd:md_identifier>
# <gmd:code>
# <gco:characterstring>http://asdd.ga.gov.au/asdd/profileinfo/anzlic-jurisdic.xml#anzlic-jurisdic</gco:characterstring>
# </gmd:code>
# </gmd:md_identifier>
# </gmd:identifier>
# <gmd:citedresponsibleparty>
# <gmd:ci_responsibleparty>
# <gmd:organisationname>
# <gco:characterstring>ANZLIC the Spatial Information Council</gco:characterstring>
# </gmd:organisationname>
# <gmd:role>
# <gmd:ci_rolecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#CI_RoleCode" codelistvalue="custodian">custodian</gmd:ci_rolecode>
# </gmd:role>
# </gmd:ci_responsibleparty>
# </gmd:citedresponsibleparty>
# </gmd:ci_citation>
# </gmd:thesaurusname>
# </gmd:md_keywords>
# </gmd:descriptivekeywords>
# <gmd:descriptivekeywords>
# <gmd:md_keywords>
# <gmd:keyword>
# <gco:characterstring>ABS</gco:characterstring>
# </gmd:keyword>
# <gmd:keyword>
# <gco:characterstring>ASGS</gco:characterstring>
# </gmd:keyword>
# <gmd:keyword>
# <gco:characterstring>BOUNDARIES - Statistical</gco:characterstring>
# </gmd:keyword>
# <gmd:keyword>
# <gco:characterstring>STATISTICAL GEOGRAPHY</gco:characterstring>
# </gmd:keyword>
# <gmd:type>
# <gmd:md_keywordtypecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#MD_KeywordTypeCode" codelistvalue="theme">theme</gmd:md_keywordtypecode>
# </gmd:type>
# <gmd:thesaurusname>
# <gmd:ci_citation>
# <gmd:title>
# <gco:characterstring>ANZLIC Search Words</gco:characterstring>
# </gmd:title>
# <gmd:date>
# <gmd:ci_date>
# <gmd:date>
# <gco:date>2008-05-16</gco:date>
# </gmd:date>
# <gmd:datetype>
# <gmd:ci_datetypecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#CI_DateTypeCode" codelistvalue="revision">revision</gmd:ci_datetypecode>
# </gmd:datetype>
# </gmd:ci_date>
# </gmd:date>
# <gmd:edition>
# <gco:characterstring>Version 2.1</gco:characterstring>
# </gmd:edition>
# <gmd:editiondate>
# <gco:date>2008-05-16</gco:date>
# </gmd:editiondate>
# <gmd:identifier>
# <gmd:md_identifier>
# <gmd:code>
# <gco:characterstring>http://asdd.ga.gov.au/asdd/profileinfo/anzlic-theme.xml#anzlic-theme</gco:characterstring>
# </gmd:code>
# </gmd:md_identifier>
# </gmd:identifier>
# <gmd:citedresponsibleparty>
# <gmd:ci_responsibleparty>
# <gmd:organisationname>
# <gco:characterstring>ANZLIC the Spatial Information Council</gco:characterstring>
# </gmd:organisationname>
# <gmd:role>
# <gmd:ci_rolecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#CI_RoleCode" codelistvalue="custodian">custodian</gmd:ci_rolecode>
# </gmd:role>
# </gmd:ci_responsibleparty>
# </gmd:citedresponsibleparty>
# </gmd:ci_citation>
# </gmd:thesaurusname>
# </gmd:md_keywords>
# </gmd:descriptivekeywords>
# <gmd:resourceconstraints>
# <gmd:md_legalconstraints>
# <gmd:uselimitation>
# <gco:characterstring>Unless otherwise noted, content is licensed under a Creative Commons Attribution 4.0 International (CC BY 4.0) </gco:characterstring>
# </gmd:uselimitation>
# <gmd:useconstraints>
# <gmd:md_restrictioncode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#MD_RestrictionCode" codelistvalue="license">license</gmd:md_restrictioncode>
# </gmd:useconstraints>
# </gmd:md_legalconstraints>
# </gmd:resourceconstraints>
# <gmd:spatialrepresentationtype>
# <gmd:md_spatialrepresentationtypecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#MD_SpatialRepresentationTypeCode" codelistvalue="vector">vector</gmd:md_spatialrepresentationtypecode>
# </gmd:spatialrepresentationtype>
# <gmd:language>
# <gco:characterstring>eng</gco:characterstring>
# </gmd:language>
# <gmd:characterset>
# <gmd:md_charactersetcode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#MD_CharacterSetCode" codelistvalue="utf8">utf8</gmd:md_charactersetcode>
# </gmd:characterset>
# <gmd:topiccategory>
# <gmd:md_topiccategorycode>boundaries</gmd:md_topiccategorycode>
# </gmd:topiccategory>
# <gmd:extent>
# <gmd:ex_extent>
# <gmd:geographicelement>
# <gmd:ex_geographicboundingbox>
# <gmd:westboundlongitude>
# <gco:decimal>96.0</gco:decimal>
# </gmd:westboundlongitude>
# <gmd:eastboundlongitude>
# <gco:decimal>169.0</gco:decimal>
# </gmd:eastboundlongitude>
# <gmd:southboundlatitude>
# <gco:decimal>-45.0</gco:decimal>
# </gmd:southboundlatitude>
# <gmd:northboundlatitude>
# <gco:decimal>-8.0</gco:decimal>
# </gmd:northboundlatitude>
# </gmd:ex_geographicboundingbox>
# </gmd:geographicelement>
# </gmd:ex_extent>
# </gmd:extent>
# </gmd:md_dataidentification>
# </gmd:identificationinfo>
# <gmd:distributioninfo>
# <gmd:md_distribution>
# <gmd:distributor>
# <gmd:md_distributor>
# <gmd:distributorcontact>
# <gmd:ci_responsibleparty>
# <gmd:individualname gco:nilreason="NA">
# <gco:characterstring></gco:characterstring>
# </gmd:individualname>
# <gmd:organisationname>
# <gco:characterstring>Australian Bureau of Statistics (ABS)</gco:characterstring>
# </gmd:organisationname>
# <gmd:positionname>
# <gco:characterstring>Customer Assistance Service</gco:characterstring>
# </gmd:positionname>
# <gmd:contactinfo>
# <gmd:ci_contact>
# <gmd:phone>
# <gmd:ci_telephone>
# <gmd:voice>
# <gco:characterstring>1300 135 070</gco:characterstring>
# </gmd:voice>
# <gmd:facsimile gco:nilreason="missing">
# <gco:characterstring></gco:characterstring>
# </gmd:facsimile>
# </gmd:ci_telephone>
# </gmd:phone>
# <gmd:address>
# <gmd:ci_address>
# <gmd:deliverypoint>
# <gco:characterstring>Australian Bureau of Statistics (ABS)</gco:characterstring>
# </gmd:deliverypoint>
# <gmd:city>
# <gco:characterstring>BELCONNEN</gco:characterstring>
# </gmd:city>
# <gmd:administrativearea>
# <gco:characterstring>ACT</gco:characterstring>
# </gmd:administrativearea>
# <gmd:postalcode>
# <gco:characterstring>2616</gco:characterstring>
# </gmd:postalcode>
# <gmd:country>
# <gco:characterstring>Australia</gco:characterstring>
# </gmd:country>
# <gmd:electronicmailaddress>
# <gco:characterstring>client.services@abs.gov.au</gco:characterstring>
# </gmd:electronicmailaddress>
# </gmd:ci_address>
# </gmd:address>
# </gmd:ci_contact>
# </gmd:contactinfo>
# <gmd:role>
# <gmd:ci_rolecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#CI_RoleCode" codelistvalue="distributor">distributor</gmd:ci_rolecode>
# </gmd:role>
# </gmd:ci_responsibleparty>
# </gmd:distributorcontact>
# <gmd:distributionorderprocess>
# <gmd:md_standardorderprocess>
# <gmd:fees>
# <gco:characterstring>Free to download from website</gco:characterstring>
# </gmd:fees>
# <gmd:orderinginstructions>
# <gco:characterstring>Download from website</gco:characterstring>
# </gmd:orderinginstructions>
# </gmd:md_standardorderprocess>
# </gmd:distributionorderprocess>
# <gmd:distributorformat>
# <gmd:md_format>
# <gmd:name>
# <gco:characterstring>Shape (shp)</gco:characterstring>
# </gmd:name>
# <gmd:version>
# <gco:characterstring>Edition 3 2021</gco:characterstring>
# </gmd:version>
# <gmd:specification>
# <gco:characterstring>ESRI Shape File</gco:characterstring>
# </gmd:specification>
# </gmd:md_format>
# </gmd:distributorformat>
# <gmd:distributortransferoptions>
# <gmd:md_digitaltransferoptions>
# <gmd:online>
# <gmd:ci_onlineresource>
# <gmd:linkage>
# <gmd:url>https://www.abs.gov.au/statistics/standards/australian-statistical-geography-standard-asgs-edition-3/jul2021-jun2026</gmd:url>
# </gmd:linkage>
# </gmd:ci_onlineresource>
# </gmd:online>
# <gmd:offline>
# <gmd:md_medium>
# <gmd:name>
# <gmd:md_mediumnamecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#MD_MediumNameCode" codelistvalue="onLine">onLine</gmd:md_mediumnamecode>
# </gmd:name>
# </gmd:md_medium>
# </gmd:offline>
# </gmd:md_digitaltransferoptions>
# </gmd:distributortransferoptions>
# </gmd:md_distributor>
# </gmd:distributor>
# <gmd:distributor>
# <gmd:md_distributor>
# <gmd:distributorcontact>
# <gmd:ci_responsibleparty>
# <gmd:individualname gco:nilreason="missing">
# <gco:characterstring></gco:characterstring>
# </gmd:individualname>
# <gmd:organisationname>
# <gco:characterstring>Australian Bureau of Statistics (ABS)</gco:characterstring>
# </gmd:organisationname>
# <gmd:positionname>
# <gco:characterstring>Customer Assistance Service</gco:characterstring>
# </gmd:positionname>
# <gmd:contactinfo>
# <gmd:ci_contact>
# <gmd:phone>
# <gmd:ci_telephone>
# <gmd:voice>
# <gco:characterstring>1300 135 070</gco:characterstring>
# </gmd:voice>
# <gmd:facsimile gco:nilreason="missing">
# <gco:characterstring></gco:characterstring>
# </gmd:facsimile>
# </gmd:ci_telephone>
# </gmd:phone>
# <gmd:address>
# <gmd:ci_address>
# <gmd:deliverypoint>
# <gco:characterstring>Australian Bureau of Statistics (ABS)</gco:characterstring>
# </gmd:deliverypoint>
# <gmd:city>
# <gco:characterstring>BELCONNEN</gco:characterstring>
# </gmd:city>
# <gmd:administrativearea>
# <gco:characterstring>ACT</gco:characterstring>
# </gmd:administrativearea>
# <gmd:postalcode>
# <gco:characterstring>2616</gco:characterstring>
# </gmd:postalcode>
# <gmd:country>
# <gco:characterstring>Australia</gco:characterstring>
# </gmd:country>
# <gmd:electronicmailaddress>
# <gco:characterstring>client.services@abs.gov.au</gco:characterstring>
# </gmd:electronicmailaddress>
# </gmd:ci_address>
# </gmd:address>
# </gmd:ci_contact>
# </gmd:contactinfo>
# <gmd:role>
# <gmd:ci_rolecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#CI_RoleCode" codelistvalue="distributor">distributor</gmd:ci_rolecode>
# </gmd:role>
# </gmd:ci_responsibleparty>
# </gmd:distributorcontact>
# <gmd:distributionorderprocess>
# <gmd:md_standardorderprocess>
# <gmd:fees>
# <gco:characterstring>Free to download from website.</gco:characterstring>
# </gmd:fees>
# <gmd:orderinginstructions>
# <gco:characterstring>Download from website</gco:characterstring>
# </gmd:orderinginstructions>
# </gmd:md_standardorderprocess>
# </gmd:distributionorderprocess>
# <gmd:distributorformat>
# <gmd:md_format>
# <gmd:name>
# <gco:characterstring>GeoPackage (gpkg)</gco:characterstring>
# </gmd:name>
# <gmd:version>
# <gco:characterstring>Edition 3 2021</gco:characterstring>
# </gmd:version>
# <gmd:specification>
# <gco:characterstring>OGC GeoPackage www.geopackage.org/</gco:characterstring>
# </gmd:specification>
# </gmd:md_format>
# </gmd:distributorformat>
# <gmd:distributortransferoptions>
# <gmd:md_digitaltransferoptions>
# <gmd:online>
# <gmd:ci_onlineresource>
# <gmd:linkage>
# <gmd:url>https://www.abs.gov.au/statistics/standards/australian-statistical-geography-standard-asgs-edition-3/jul2021-jun2026</gmd:url>
# </gmd:linkage>
# </gmd:ci_onlineresource>
# </gmd:online>
# <gmd:offline>
# <gmd:md_medium>
# <gmd:name>
# <gmd:md_mediumnamecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#MD_MediumNameCode" codelistvalue="onLine">onLine</gmd:md_mediumnamecode>
# </gmd:name>
# </gmd:md_medium>
# </gmd:offline>
# </gmd:md_digitaltransferoptions>
# </gmd:distributortransferoptions>
# </gmd:md_distributor>
# </gmd:distributor>
# </gmd:md_distribution>
# </gmd:distributioninfo>
# <gmd:dataqualityinfo>
# <gmd:dq_dataquality>
# <gmd:scope>
# <gmd:dq_scope>
# <gmd:level>
# <gmd:md_scopecode codelist="http://asdd.ga.gov.au/asdd/profileinfo/gmxCodelists.xml#MD_ScopeCode" codelistvalue="dataset">dataset</gmd:md_scopecode>
# </gmd:level>
# <gmd:leveldescription>
# <gmd:md_scopedescription>
# <gmd:other>
# <gco:characterstring>dataset</gco:characterstring>
# </gmd:other>
# </gmd:md_scopedescription>
# </gmd:leveldescription>
# </gmd:dq_scope>
# </gmd:scope>
# <gmd:lineage>
# <gmd:li_lineage>
# <gmd:statement>
# <gco:characterstring>Statistical Area Level 2 (SA2) boundaries were created using various sources including the Geoscape digital datasets and ABS boundaries, zoning information from state planning agencies and imagery.
# State borders are aligned to Australia's Land Borders data set produced by Geoscience Australia and available from http://pid.geoscience.gov.au/dataset/ga/140044
# Positional Accuracy:
# Positional accuracy is an assessment of the closeness of the location of the spatial objects in relation to their true positions on the earth's surface.
# The positional accuracy includes:
# - a horizontal accuracy assessment; and
# - a vertical accuracy assessment.
# Positional accuracy for ABS boundaries is dependent on the accuracy of the features they have been aligned to.
# ABS boundaries are aligned to a number of layers supplied by Geoscape with an accuracy of +/-50mm.
# Geoscape layers and their positional accuracy are as follows:
# - Transport and Topography: +/-2 metres in urban areas and +/- 10 metres in rural and remote areas;
# - CadLite: +/- 2 metres in urban areas and +/- 10 metres in rural and remote areas;
# - Administrative Boundaries: derived from the cadastre data from each Australian State and Territory jurisdiction;
# - Greenspace and Hydrology: 90% of well-defined features are within 1mm (at plot scale) of their true position, e.g. 1:500 equates to +/- 0.5 metre and 1:25,000 equates to +/- 25 metres.
# No "shift" of data as a means of "cartographic enhancement" to facilitate presentation has been employed for any real world feature.
# Precision:
# Boundary coordinates have been rounded to 8 decimal places, equivalent to 1.1132mm at the equator. All ABS boundaries have been generalised to 5cm with a 7.5cm shared boundary tolerance. </gco:characterstring>
# </gmd:statement>
# </gmd:li_lineage>
# </gmd:lineage>
# </gmd:dq_dataquality>
# </gmd:dataqualityinfo>
# </gmd:md_metadata><!--METValidation=True-->
# </body></html>

# %%
GDA2020 = 7844
GDA94 = 4283
# defined the SRID

# %% [markdown]
# ### The read_file function in the Geopandas libary is used to read the shapefile containing the Spatial Data

# %%
f_sa2 = gpd.read_file("SA2_2021_AUST_SHP_GDA2020/SA2_2021_AUST_GDA2020.shp")
f_sa2
# Out:
#      SA2_CODE21                            SA2_NAME21 CHG_FLAG21  CHG_LBL21  \
# 0     101021007                             Braidwood          0  No change
# 1     101021008                               Karabar          0  No change
# 2     101021009                            Queanbeyan          0  No change
# 3     101021010                     Queanbeyan - East          0  No change
# 4     101021012       Queanbeyan West - Jerrabomberra          0  No change
# ...         ...                                   ...        ...        ...
# 2468  901031003                            Jervis Bay          0  No change
# 2469  901041004                        Norfolk Island          0  No change
# 2470  997979799  Migratory - Offshore - Shipping (OT)          0  No change
# 2471  999999499                 No usual address (OT)          0  No change
# 2472  ZZZZZZZZZ                     Outside Australia          1        New
#
#      SA3_CODE21                            SA3_NAME21 SA4_CODE21  \
# 0         10102                            Queanbeyan        101
# 1         10102                            Queanbeyan        101
# 2         10102                            Queanbeyan        101
# 3         10102                            Queanbeyan        101
# 4         10102                            Queanbeyan        101
# ...         ...                                   ...        ...
# 2468      90103                            Jervis Bay        901
# 2469      90104                        Norfolk Island        901
# 2470      99797  Migratory - Offshore - Shipping (OT)        997
# 2471      99999                 No usual address (OT)        999
# 2472      ZZZZZ                     Outside Australia        ZZZ
#
#                                 SA4_NAME21 GCC_CODE21  \
# 0                           Capital Region      1RNSW
# 1                           Capital Region      1RNSW
# 2                           Capital Region      1RNSW
# 3                           Capital Region      1RNSW
# 4                           Capital Region      1RNSW
# ...                                    ...        ...
# 2468                     Other Territories      9OTER
# 2469                     Other Territories      9OTER
# 2470  Migratory - Offshore - Shipping (OT)      99799
# 2471                 No usual address (OT)      99499
# 2472                     Outside Australia      ZZZZZ
#
#                                 GCC_NAME21 STE_CODE21         STE_NAME21  \
# 0                              Rest of NSW          1    New South Wales
# 1                              Rest of NSW          1    New South Wales
# 2                              Rest of NSW          1    New South Wales
# 3                              Rest of NSW          1    New South Wales
# 4                              Rest of NSW          1    New South Wales
# ...                                    ...        ...                ...
# 2468                     Other Territories          9  Other Territories
# 2469                     Other Territories          9  Other Territories
# 2470  Migratory - Offshore - Shipping (OT)          9  Other Territories
# 2471                 No usual address (OT)          9  Other Territories
# 2472                     Outside Australia          Z  Outside Australia
#
#      AUS_CODE21         AUS_NAME21  AREASQKM21  \
# 0           AUS          Australia   3418.3525
# 1           AUS          Australia      6.9825
# 2           AUS          Australia      4.7620
# 3           AUS          Australia     13.0032
# 4           AUS          Australia     13.6748
# ...         ...                ...         ...
# 2468        AUS          Australia     67.2296
# 2469        AUS          Australia     38.6510
# 2470        AUS          Australia         NaN
# 2471        AUS          Australia         NaN
# 2472        ZZZ  Outside Australia         NaN
#
#                                              LOCI_URI21  \
# 0     http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 1     http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2     http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 3     http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 4     http://linked.data.gov.au/dataset/asgsed3/SA2/...
# ...                                                 ...
# 2468  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2469  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2470  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2471  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 2472  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                                geometry
# 0     POLYGON ((149.58424 -35.44426, 149.58444 -35.4...
# 1     POLYGON ((149.21899 -35.36738, 149.21800 -35.3...
# 2     POLYGON ((149.21326 -35.34325, 149.21619 -35.3...
# 3     POLYGON ((149.24034 -35.34781, 149.24024 -35.3...
# 4     POLYGON ((149.19572 -35.36126, 149.19970 -35.3...
# ...                                                 ...
# 2468  MULTIPOLYGON (((150.69567 -35.18295, 150.69556...
# 2469  MULTIPOLYGON (((167.96325 -29.07212, 167.96326...
# 2470                                               None
# 2471                                               None
# 2472                                               None
#
# [2473 rows x 17 columns]

# %%
f_sa2["geometry"].crs.name
# Out:
# 'GDA2020'

# %% [markdown]
# ### filter the database to the Greater Syndey ensuring our focus region

# %%
f_sa2 = f_sa2[f_sa2['GCC_NAME21'] == 'Greater Sydney']
f_sa2.head()
# Out:
#    SA2_CODE21                   SA2_NAME21 CHG_FLAG21  CHG_LBL21 SA3_CODE21  \
# 28  102011028     Avoca Beach - Copacabana          0  No change      10201
# 29  102011029  Box Head - MacMasters Beach          0  No change      10201
# 30  102011030              Calga - Kulnura          0  No change      10201
# 31  102011031          Erina - Green Point          0  No change      10201
# 32  102011032        Gosford - Springfield          0  No change      10201
#
#    SA3_NAME21 SA4_CODE21     SA4_NAME21 GCC_CODE21      GCC_NAME21 STE_CODE21  \
# 28    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 29    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 30    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 31    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
# 32    Gosford        102  Central Coast      1GSYD  Greater Sydney          1
#
#          STE_NAME21 AUS_CODE21 AUS_NAME21  AREASQKM21  \
# 28  New South Wales        AUS  Australia      6.4376
# 29  New South Wales        AUS  Australia     32.0802
# 30  New South Wales        AUS  Australia    767.9512
# 31  New South Wales        AUS  Australia     33.7934
# 32  New South Wales        AUS  Australia     16.9123
#
#                                            LOCI_URI21  \
# 28  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 29  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 30  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 31  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 32  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
#                                              geometry
# 28  POLYGON ((151.41373 -33.46558, 151.41362 -33.4...
# 29  POLYGON ((151.37484 -33.50052, 151.37507 -33.5...
# 30  MULTIPOLYGON (((151.20449 -33.53280, 151.20448...
# 31  POLYGON ((151.37194 -33.43698, 151.37288 -33.4...
# 32  POLYGON ((151.32349 -33.42779, 151.32342 -33.4...

# %% [markdown]
# ### By reading the database, the geometry column have both polygon geometry type and multipolygon geometry type. In order to convert the polygons into multipolygon so that the geometry type in the geometry column is consistent.
# ### A function for WKT conversion is defined to enable the polygons to convert into multipolygon as shown below.

# %%
def create_wkt_element(geom, srid):
    if geom.geom_type == 'Polygon':
        geom = MultiPolygon([geom])
    return WKTElement(geom.wkt, srid)

f_sa2co = f_sa2.copy()
f_sa2['geom'] = f_sa2co['geometry'].apply(lambda x: create_wkt_element(geom=x, srid = GDA2020))
f_sa2 = f_sa2.drop(columns="geometry")
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %% [markdown]
# ### As only the data about Statistical Area Level 2 is relevant to our other databases and the database is already filtered down to Greater Sydney, so the columns about the area region (such as GCC (Greater Captal City Statistical Areas), STE (States and Territories)) and other area level (such as SA3, SA3) are dropped. Thus, only three columns were considered as useful which are kept.

# %%
f_sa2 = f_sa2[['SA2_CODE21', 'SA2_NAME21', 'geom']]
f_sa2 = f_sa2.rename(columns={'SA2_CODE21': 'sa2_code', 'SA2_NAME21': 'sa2_name'})
f_sa2['sa2_code']=f_sa2['sa2_code'].apply(int)
f_sa2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 373 entries, 28 to 641
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sa2_code  373 non-null    int64
#  1   sa2_name  373 non-null    object
#  2   geom      373 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 11.7+ KB

# %%
f_sa2 = f_sa2.dropna()

# %% [markdown]
# ### Create the table in the SQL server and insert the information in the database into the table.

# %%
conn.execute(text("""
 drop table if exists sa2 CASCADE;
 create table sa2(
     sa2_code Numeric Primary Key,
     sa2_name VARCHAR(100),
     geom GEOMETRY(MULTIPOLYGON, 7844)
);"""))

# %%
f_sa2.to_sql("sa2", conn, if_exists='replace', index=False, dtype={'geom': Geometry('MULTIPOLYGON', GDA2020)})

query(conn, "select * from sa2")
# Out:
#       sa2_code                     sa2_name  \
# 0    102011028     Avoca Beach - Copacabana
# 1    102011029  Box Head - MacMasters Beach
# 2    102011030              Calga - Kulnura
# 3    102011031          Erina - Green Point
# 4    102011032        Gosford - Springfield
# ..         ...                          ...
# 368  128021537          Royal National Park
# 369  128021538        Sutherland - Kirrawee
# 370  128021607                     Engadine
# 371  128021608         Loftus - Yarrawarrah
# 372  128021609             Woronora Heights
#
#                                                   geom
# 0    0106000020A41E0000010000000103000000010000005E...
# 1    0106000020A41E00000100000001030000000100000010...
# 2    0106000020A41E00000200000001030000000100000085...
# 3    0106000020A41E00000100000001030000000100000041...
# 4    0106000020A41E0000010000000103000000010000007E...
# ..                                                 ...
# 368  0106000020A41E00000100000001030000000100000046...
# 369  0106000020A41E00000100000001030000000100000089...
# 370  0106000020A41E0000010000000103000000010000008E...
# 371  0106000020A41E000001000000010300000001000000A1...
# 372  0106000020A41E000001000000010300000001000000F0...
#
# [373 rows x 3 columns]

# %% [markdown]
# # The below is the School dataset.

# %% [markdown]
# ### The function read_file from the Geopandas library is used to read the shapefiles with the spatial data.
# ### As there are three different categories of school according to the given databases, they are read separately.

# %%
f_school_future = gpd.read_file("catchments/catchments_future.shp")
f_school_primary = gpd.read_file("catchments/catchments_primary.shp")
f_school_secondary = gpd.read_file("catchments/catchments_secondary.shp")

# %%
f_school_future["geometry"].crs.name
# Out:
# 'GDA94'

# %%
f_school_future.to_crs(GDA2020, inplace = True)
f_school_primary.to_crs(GDA2020, inplace = True)
f_school_secondary.to_crs(GDA2020, inplace = True)

# %%
f_school_future.head(5)
# Out:
#   USE_ID CATCH_TYPE             USE_DESC  ADD_DATE  KINDERGART  YEAR1  YEAR2  \
# 0   8416  HIGH_COED       Ku-ring-gai HS  20230114           0      0      0
# 1   8161  HIGH_BOYS         Randwick BHS  20200220           0      0      0
# 2   8539  HIGH_COED  SSC Blackwattle Bay  20220609           0      0      0
# 3   8400  HIGH_COED           St Ives HS  20230114           0      0      0
# 4   8555  HIGH_COED          Rose Bay SC  20200220           0      0      0
#
#    YEAR3  YEAR4  YEAR5  YEAR6  YEAR7  YEAR8  YEAR9  YEAR10  YEAR11  YEAR12  \
# 0      0      0      0      0   2024   2024   2024    2024    2024    2024
# 1      0      0      0      0   2024   2024   2024    2024    2024    2024
# 2      0      0      0      0      0      0      0       0    2024    2024
# 3      0      0      0      0   2024   2024   2024    2024    2024    2024
# 4      0      0      0      0   2024   2024   2024    2024    2024    2024
#
#                                             geometry
# 0  POLYGON ((151.19849 -33.53989, 151.19945 -33.5...
# 1  POLYGON ((151.27152 -33.91401, 151.27152 -33.9...
# 2  POLYGON ((151.15293 -33.83938, 151.16145 -33.8...
# 3  POLYGON ((151.17794 -33.69819, 151.17859 -33.6...
# 4  POLYGON ((151.28073 -33.83286, 151.28095 -33.8...

# %%
f_school_primary.head()
# Out:
#   USE_ID CATCH_TYPE         USE_DESC  ADD_DATE KINDERGART YEAR1 YEAR2 YEAR3  \
# 0   2838    PRIMARY       Parklea PS  20181210          Y     Y     Y     Y
# 1   2404    PRIMARY    Lindfield EPS  20211219          Y     Y     Y     Y
# 2   4393    PRIMARY  Carlingford WPS  20220223          Y     Y     Y     Y
# 3   4615    PRIMARY   Caddies Ck  PS  20181210          Y     Y     Y     Y
# 4   3918    PRIMARY       Killara PS  20211219          Y     Y     Y     Y
#
#   YEAR4 YEAR5 YEAR6 YEAR7 YEAR8 YEAR9 YEAR10 YEAR11 YEAR12 PRIORITY  \
# 0     Y     Y     Y     N     N     N      N      N      N     None
# 1     Y     Y     Y     N     N     N      N      N      N     None
# 2     Y     Y     Y     N     N     N      N      N      N     None
# 3     Y     Y     Y     N     N     N      N      N      N     None
# 4     Y     Y     Y     N     N     N      N      N      N     None
#
#                                             geometry
# 0  POLYGON ((150.93564 -33.71611, 150.93716 -33.7...
# 1  POLYGON ((151.18337 -33.74747, 151.18443 -33.7...
# 2  POLYGON ((151.04519 -33.77302, 151.04527 -33.7...
# 3  POLYGON ((150.92568 -33.72959, 150.92602 -33.7...
# 4  POLYGON ((151.15379 -33.75585, 151.15405 -33.7...

# %%
f_school_secondary.head()
# Out:
#   USE_ID CATCH_TYPE         USE_DESC  ADD_DATE KINDERGART YEAR1 YEAR2 YEAR3  \
# 0   8503  HIGH_COED     Billabong HS  20200507          N     N     N     N
# 1   8266  HIGH_COED  James Fallon HS  20200507          N     N     N     N
# 2   8505  HIGH_COED        Murray HS  20200507          N     N     N     N
# 3   8458  HIGH_COED     Kingswood HS  20201016          N     N     N     N
# 4   8559  HIGH_COED       Jamison HS  20201016          N     N     N     N
#
#   YEAR4 YEAR5 YEAR6 YEAR7 YEAR8 YEAR9 YEAR10 YEAR11 YEAR12 PRIORITY  \
# 0     N     N     N     Y     Y     Y      Y      Y      Y     None
# 1     N     N     N     Y     Y     Y      Y      Y      Y     None
# 2     N     N     N     Y     Y     Y      Y      Y      Y     None
# 3     N     N     N     Y     Y     Y      Y      Y      Y     None
# 4     N     N     N     Y     Y     Y      Y      Y      Y     None
#
#                                             geometry
# 0  POLYGON ((146.67183 -35.31442, 146.68930 -35.3...
# 1  POLYGON ((147.08734 -35.86270, 147.10414 -35.8...
# 2  POLYGON ((146.81448 -35.78339, 146.81250 -35.7...
# 3  MULTIPOLYGON (((150.68600 -33.74029, 150.68632...
# 4  POLYGON ((150.69514 -33.75626, 150.68937 -33.7...

# %% [markdown]
# ### As all of the three database contain the geometry column whereas include both polygon type and multipolygon type, the function defined above in the section of cleaning SA2 dataset was used to convert the polygon geometry type to multipolygon for all three databases to ensure consistent geometry type in the column.
#
# ### As shown by the database above, there are columns about the school is teaching what year levels (f_school_primary and f_school_secondary). The year level columns are not useful as we can tell what year levels they are teaching by their CATCH_TYPE, so these columns are dropped. Moreover, as the 'Priority' column contains a lot of 'None' values in all three database, it is dropped.

# %%
pri_schoolog = f_school_primary.copy()  # creating a copy of the original for later
f_school_primary['geom'] = pri_schoolog['geometry'].apply(lambda x: create_wkt_element(geom=x,srid=GDA2020))  # applying the function
f_school_primary = f_school_primary.drop(columns="geometry")  # deleting the old copy

f_school_primary=f_school_primary.drop(columns = "PRIORITY")
f_school_primary=f_school_primary.drop(columns = ['ADD_DATE', 'KINDERGART', 'YEAR1', 'YEAR2', 'YEAR3', 'YEAR4', 'YEAR5', 'YEAR6', 
                                                  'YEAR7','YEAR8', 'YEAR9', 'YEAR10', 'YEAR11', 'YEAR12'])

fu_schoolog = f_school_future.copy()  # creating a copy of the original for later
f_school_future['geom'] = fu_schoolog['geometry'].apply(lambda x: create_wkt_element(geom=x,srid=GDA2020))  # applying the function
f_school_future = f_school_future.drop(columns="geometry")  # deleting the old copy

f_school_future=f_school_future.drop(columns = ['ADD_DATE', 'KINDERGART', 'YEAR1', 'YEAR2', 'YEAR3', 'YEAR4', 'YEAR5', 'YEAR6', 
                                                  'YEAR7','YEAR8', 'YEAR9', 'YEAR10', 'YEAR11', 'YEAR12'])

sec_schoolog = f_school_secondary.copy()  # creating a copy of the original for later
f_school_secondary['geom'] = sec_schoolog['geometry'].apply(lambda x: create_wkt_element(geom=x,srid=GDA2020))  # applying the function
f_school_secondary = f_school_secondary.drop(columns="geometry")  # deleting the old copy

f_school_secondary=f_school_secondary.drop(columns = "PRIORITY")
f_school_secondary=f_school_secondary.drop(columns = {"ADD_DATE", "KINDERGART", "YEAR1", "YEAR2", "YEAR3", "YEAR4", "YEAR5", "YEAR6", 
                                                      "YEAR7", "YEAR8", "YEAR9", "YEAR10", "YEAR11", "YEAR12"})

# %%
f_school_primary.head()
# Out:
#   USE_ID CATCH_TYPE         USE_DESC  \
# 0   2838    PRIMARY       Parklea PS
# 1   2404    PRIMARY    Lindfield EPS
# 2   4393    PRIMARY  Carlingford WPS
# 3   4615    PRIMARY   Caddies Ck  PS
# 4   3918    PRIMARY       Killara PS
#
#                                                 geom
# 0  MULTIPOLYGON (((150.9356439933613 -33.71610839...
# 1  MULTIPOLYGON (((151.18336949631575 -33.7474713...
# 2  MULTIPOLYGON (((151.04518757155512 -33.7730194...
# 3  MULTIPOLYGON (((150.9256787686052 -33.72959029...
# 4  MULTIPOLYGON (((151.1537938309681 -33.75584905...

# %%
f_school_future.head()
# Out:
#   USE_ID CATCH_TYPE             USE_DESC  \
# 0   8416  HIGH_COED       Ku-ring-gai HS
# 1   8161  HIGH_BOYS         Randwick BHS
# 2   8539  HIGH_COED  SSC Blackwattle Bay
# 3   8400  HIGH_COED           St Ives HS
# 4   8555  HIGH_COED          Rose Bay SC
#
#                                                 geom
# 0  MULTIPOLYGON (((151.19849465239312 -33.5398860...
# 1  MULTIPOLYGON (((151.2715207191065 -33.91400564...
# 2  MULTIPOLYGON (((151.1529291511585 -33.83937945...
# 3  MULTIPOLYGON (((151.17794275650013 -33.6981874...
# 4  MULTIPOLYGON (((151.28072818401563 -33.8328602...

# %%
f_school_future = f_school_future.rename(columns = {'USE_ID' : 'use_id', 'CATCH_TYPE' : 'catch_type', 
                                                    'USE_DESC' : 'use_desc'})
f_school_primary = f_school_primary.rename(columns = {'USE_ID' : 'use_id', 'CATCH_TYPE' : 'catch_type', 
                                                    'USE_DESC' : 'use_desc'})
f_school_secondary = f_school_secondary.rename(columns = {'USE_ID' : 'use_id', 'CATCH_TYPE' : 'catch_type', 
                                                    'USE_DESC' : 'use_desc'})

# %% [markdown]
# ### The below is to create the corresponding table in the SQL server and insert the database content into the SQL table so that we can access the database through SQL queries.

# %%
conn.execute(text("""
DROP TABLE IF EXISTS primary_school;
CREATE TABLE primary_school (
    use_id integer Primary Key,
    catch_type VARCHAR(10),
    used_desc VARCHAR(100),
    geom GEOMETRY(MULTIPOLYGON,7844)
);"""
))

conn.execute(text("""
DROP TABLE IF EXISTS secondary_school;
CREATE TABLE secondary_school (
    use_id integer Primary Key,
    catch_type VARCHAR(10),
    used_desc VARCHAR(100),
    geom GEOMETRY(MULTIPOLYGON,7844)
);"""
))

conn.execute(text("""
DROP TABLE IF EXISTS future_school;
CREATE TABLE future_school (
    use_id integer Primary Key,
    catch_type VARCHAR(10),
    used_desc VARCHAR(100),
    geom GEOMETRY(MULTIPOLYGON,7844)
);"""
))

# %%
f_school_primary = f_school_primary.dropna()
f_school_secondary = f_school_secondary.dropna()
f_school_future = f_school_future.dropna()

# %%
f_school_primary.to_sql("primary_school", conn, if_exists='replace', index=False, dtype={'geom': Geometry('MULTIPOLYGON', GDA2020)})
query(conn, "select * from primary_school")
# Out:
#      use_id catch_type         use_desc  \
# 0      2838    PRIMARY       Parklea PS
# 1      2404    PRIMARY    Lindfield EPS
# 2      4393    PRIMARY  Carlingford WPS
# 3      4481    PRIMARY    St Andrews PS
# 4      4615    PRIMARY   Caddies Ck  PS
# ...     ...        ...              ...
# 1657   2409    PRIMARY      Lismore SPS
# 1658   4383    PRIMARY   E A Southee PS
# 1659   3275    PRIMARY    Tumbarumba PS
# 1660   2239    PRIMARY       Jindera PS
# 1661   3594    PRIMARY         Louth PS
#
#                                                    geom
# 0     0106000020A41E00000100000001030000000100000078...
# 1     0106000020A41E000001000000010300000001000000BE...
# 2     0106000020A41E00000100000001030000000100000065...
# 3     0106000020A41E00000100000001030000000100000040...
# 4     0106000020A41E00000100000001030000000100000056...
# ...                                                 ...
# 1657  0106000020A41E000001000000010300000001000000C9...
# 1658  0106000020A41E000001000000010300000001000000B9...
# 1659  0106000020A41E000001000000010300000001000000C0...
# 1660  0106000020A41E000001000000010300000001000000F6...
# 1661  0106000020A41E00000100000001030000000100000094...
#
# [1662 rows x 4 columns]

# %%
f_school_secondary.to_sql("secondary_school", conn, if_exists='replace', index=False, dtype={'geom': Geometry('MULTIPOLYGON', GDA2020)})
query(conn, "select * from secondary_school")
# Out:
#     use_id    catch_type         use_desc  \
# 0     8503     HIGH_COED     Billabong HS
# 1     8266     HIGH_COED  James Fallon HS
# 2     8559     HIGH_COED       Jamison HS
# 3     8502     HIGH_COED       Tomaree HS
# 4     8505     HIGH_COED        Murray HS
# ..     ...           ...              ...
# 431   8213     HIGH_BOYS      Birrong BHS
# 432   8108     HIGH_COED      Cessnock HS
# 433   3235  CENTRAL_HIGH     Tooleybuc CS
# 434   1115  CENTRAL_HIGH     Balranald CS
# 435   2213  CENTRAL_HIGH       Ivanhoe CS
#
#                                                   geom
# 0    0106000020A41E0000010000000103000000010000006D...
# 1    0106000020A41E00000100000001030000000100000071...
# 2    0106000020A41E0000010000000103000000020000002F...
# 3    0106000020A41E0000010000000103000000010000003B...
# 4    0106000020A41E0000010000000103000000010000003F...
# ..                                                 ...
# 431  0106000020A41E00000100000001030000000100000040...
# 432  0106000020A41E000001000000010300000001000000AD...
# 433  0106000020A41E0000010000000103000000010000003E...
# 434  0106000020A41E0000010000000103000000010000005B...
# 435  0106000020A41E00000100000001030000000100000068...
#
# [436 rows x 4 columns]

# %%
f_school_future.to_sql("future_school", conn, if_exists='replace', index=False, dtype={'geom': Geometry('MULTIPOLYGON', GDA2020)})
query(conn, "select * from future_school")
# Out:
#    use_id    catch_type                use_desc  \
# 0    8416     HIGH_COED          Ku-ring-gai HS
# 1    8161     HIGH_BOYS            Randwick BHS
# 2    8539     HIGH_COED     SSC Blackwattle Bay
# 3    8286     HIGH_COED             Mt Annan HS
# 4    8400     HIGH_COED              St Ives HS
# 5    8555     HIGH_COED             Rose Bay SC
# 6    8556  CENTRAL_HIGH      Alexandria Park CS
# 7    8584     HIGH_COED  Elizabeth Macarthur HS
# 8    8913     HIGH_COED         Inner Sydney HS
# 9    8135     HIGH_COED           Parramatta HS
# 10   8290     HIGH_COED       John Edmondson HS
# 11   8916     HIGH_COED            Oran Park HS
# 12   8575     HIGH_COED       Robert Townson HS
# 13   8569     HIGH_COED           Eagle Vale HS
# 14   8435     HIGH_COED           Turramurra HS
# 15   8220    HIGH_GIRLS            Randwick GHS
# 16   8922     HIGH_COED        Jerrabomberra HS
# 17   8524     HIGH_COED              Karabar HS
# 18   8919     HIGH_COED           Bungendore HS
# 19   2899       PRIMARY       Port Macquarie PS
# 20   4411       PRIMARY             Westport PS
# 21   8116     HIGH_COED             Goulburn HS
# 22   4400       PRIMARY         St Ives Park PS
# 23   8216     HIGH_COED           Queanbeyan HS
# 24   4331       PRIMARY              St Ives PS
# 25   4524       PRIMARY             Hastings PS
# 26   8554     HIGH_COED            HSC Westport
# 27   8364     HIGH_COED      HSC Port Macquarie
# 28   8395     HIGH_COED          Pendle Hill HS
# 29   8892     HIGH_COED       Arthur Phillip HS
#
#                                                  geom
# 0   0106000020A41E00000100000001030000000100000090...
# 1   0106000020A41E0000010000000103000000010000006F...
# 2   0106000020A41E000001000000010300000001000000E3...
# 3   0106000020A41E00000100000001030000000100000099...
# 4   0106000020A41E00000100000001030000000100000060...
# 5   0106000020A41E0000010000000103000000010000000C...
# 6   0106000020A41E00000100000001030000000100000028...
# 7   0106000020A41E000001000000010300000001000000BB...
# 8   0106000020A41E00000100000001030000000100000076...
# 9   0106000020A41E0000010000000103000000010000001F...
# 10  0106000020A41E00000200000001030000000100000036...
# 11  0106000020A41E00000100000001030000000100000086...
# 12  0106000020A41E00000100000001030000000100000097...
# 13  0106000020A41E00000100000001030000000100000097...
# 14  0106000020A41E0000010000000103000000010000000B...
# 15  0106000020A41E0000010000000103000000010000006D...
# 16  0106000020A41E00000100000001030000000100000039...
# 17  0106000020A41E00000100000001030000000100000060...
# 18  0106000020A41E000001000000010300000001000000BF...
# 19  0106000020A41E000001000000010300000001000000BC...
# 20  0106000020A41E000001000000010300000001000000E2...
# 21  0106000020A41E000001000000010300000001000000EB...
# 22  0106000020A41E000001000000010300000001000000C4...
# 23  0106000020A41E00000100000001030000000100000043...
# 24  0106000020A41E00000100000001030000000100000088...
# 25  0106000020A41E00000100000001030000000100000060...
# 26  0106000020A41E000001000000010300000001000000FE...
# 27  0106000020A41E000001000000010300000001000000D7...
# 28  0106000020A41E0000010000000103000000010000004A...
# 29  0106000020A41E00000100000001030000000100000088...

# %% [markdown]
# # The below is the Businesses dataset.

# %% [markdown]
# ### Business is a csv database, so the read_csv function in pandas library is used to tranform the csv data to dataframe in python.

# %%
f_business = pd.read_csv("Businesses.csv")
f_business.head()
# Out:
#   industry_code                      industry_name   sa2_code  \
# 0             A  Agriculture, Forestry and Fishing  101021007
# 1             A  Agriculture, Forestry and Fishing  101021008
# 2             A  Agriculture, Forestry and Fishing  101021009
# 3             A  Agriculture, Forestry and Fishing  101021010
# 4             A  Agriculture, Forestry and Fishing  101021012
#
#                           sa2_name  0_to_50k_businesses  \
# 0                        Braidwood                  136
# 1                          Karabar                    6
# 2                       Queanbeyan                    6
# 3                Queanbeyan - East                    0
# 4  Queanbeyan West - Jerrabomberra                    7
#
#    50k_to_200k_businesses  200k_to_2m_businesses  2m_to_5m_businesses  \
# 0                      92                     63                    4
# 1                       3                      0                    0
# 2                       4                      3                    0
# 3                       3                      0                    0
# 4                       4                      5                    0
#
#    5m_to_10m_businesses  10m_or_more_businesses  total_businesses
# 0                     0                       0               296
# 1                     0                       0                 9
# 2                     0                       3                15
# 3                     0                       0                 3
# 4                     0                       0                16

# %% [markdown]
# ### Data Cleaning process and Filtering process
# #### drop rows and columns containing null values.
# #### Create a new column with summing up the columns with businesses containing turnover less than 2m which is the majority group among all businesses according to the website providing the data source (ABS Austrlian Bureau of Statistics), the columns with the number of businesses for each turnover range are droped due to the new column is more useful.

# %%
df_business = pd.DataFrame(f_business)
df_business.dropna(axis = 1)
df_business.dropna(axis = 0)
df_business.drop_duplicates()

business_count = {'industry_code': df_business['industry_code'], 'industry_name': df_business['industry_name'], 
                  'sa2_code': df_business['sa2_code'], 'sa2_name': df_business['sa2_name'], 
                  'turnover_value_under2m': df_business['0_to_50k_businesses'] + df_business['50k_to_200k_businesses'] + df_business['200k_to_2m_businesses'],
                  'all_businesses': df_business['total_businesses']}
business_count = pd.DataFrame(business_count)
business_count['sa2_code']=business_count['sa2_code'].apply(int)
business_count.head()
# Out:
#   industry_code                      industry_name   sa2_code  \
# 0             A  Agriculture, Forestry and Fishing  101021007
# 1             A  Agriculture, Forestry and Fishing  101021008
# 2             A  Agriculture, Forestry and Fishing  101021009
# 3             A  Agriculture, Forestry and Fishing  101021010
# 4             A  Agriculture, Forestry and Fishing  101021012
#
#                           sa2_name  turnover_value_under2m  all_businesses
# 0                        Braidwood                     291             296
# 1                          Karabar                       9               9
# 2                       Queanbeyan                      13              15
# 3                Queanbeyan - East                       3               3
# 4  Queanbeyan West - Jerrabomberra                      16              16

# %% [markdown]
# ### Create the corresponding table in the SQL server and insert the database content into the table so that we can access the database with SQL queries.

# %%
conn.execute(text("""
drop table if exists business CASCADE;
create table business (
    id INT Primary Key,
    industry_code VARCHAR(1),
    industry_name VARCHAR(100),
    sa2_code NUMERIC,
    sa2_name VARCHAR(100),
    turnover_value_under2m INTEGER,
    all_businesses INTEGER
);"""
))
business_count.to_sql('business', conn, if_exists = 'replace', index = False)
query(conn, "select * from business")
# Out:
#       industry_code                      industry_name   sa2_code  \
# 0                 A  Agriculture, Forestry and Fishing  101021007
# 1                 A  Agriculture, Forestry and Fishing  101021008
# 2                 A  Agriculture, Forestry and Fishing  101021009
# 3                 A  Agriculture, Forestry and Fishing  101021010
# 4                 A  Agriculture, Forestry and Fishing  101021012
# ...             ...                                ...        ...
# 12212             S                     Other Services  128021538
# 12213             S                     Other Services  128021607
# 12214             S                     Other Services  128021608
# 12215             S                     Other Services  128021609
# 12216             S                     Other Services  199999499
#
#                               sa2_name  turnover_value_under2m  all_businesses
# 0                            Braidwood                     291             296
# 1                              Karabar                       9               9
# 2                           Queanbeyan                      13              15
# 3                    Queanbeyan - East                       3               3
# 4      Queanbeyan West - Jerrabomberra                      16              16
# ...                                ...                     ...             ...
# 12212            Sutherland - Kirrawee                     145             152
# 12213                         Engadine                      85              87
# 12214             Loftus - Yarrawarrah                      20              22
# 12215                 Woronora Heights                       8               9
# 12216                Currently Unknown                     164             190
#
# [12217 rows x 6 columns]

# %%
business_count['industry_name'].unique()
# Out:
# array(['Agriculture, Forestry and Fishing', 'Mining', 'Manufacturing',
#        'Electricity, Gas, Water and Waste Services', 'Construction',
#        'Wholesale Trade', 'Retail Trade',
#        'Accommodation and Food Services',
#        'Transport, Postal and Warehousing',
#        'Information Media and Telecommunications',
#        'Financial and Insurance Services',
#        'Rental, Hiring and Real Estate Services',
#        'Professional, Scientific and Technical Services',
#        'Administrative and Support Services',
#        'Public Administration and Safety', 'Education and Training',
#        'Health Care and Social Assistance',
#        'Arts and Recreation Services', 'Other Services'], dtype=object)

# %% [markdown]
# # The below is Polls dataset.

# %% [markdown]
# ### This Polls dataset is also a csv database, so read_csv function in geopandas library is used to read it.

# %%
f_polls = pd.read_csv('PollingPlaces2019.csv')
f_polls.head()
# Out:
#                                                  FID state  division_id  \
# 0  aec_federal_election_polling_places_2019.fid-4...   NSW          104
# 1  aec_federal_election_polling_places_2019.fid-4...   NSW          105
# 2  aec_federal_election_polling_places_2019.fid-4...   NSW          107
# 3  aec_federal_election_polling_places_2019.fid-4...   NSW          109
# 4  aec_federal_election_polling_places_2019.fid-4...   NSW          113
#
#   division_name  polling_place_id  polling_place_type_id  \
# 0        Barton             33595                      2
# 1     Bennelong             33596                      2
# 2      Blaxland             33600                      2
# 3        Calare             33603                      2
# 4        Cowper             33716                      2
#
#         polling_place_name   premises_name premises_address_1  \
# 0  Special Hospital Team 1  Multiple sites                NaN
# 1  Special Hospital Team 1  Multiple sites                NaN
# 2  Special Hospital Team 1  Multiple sites                NaN
# 3  Special Hospital Team 1  Multiple sites                NaN
# 4  Special Hospital Team 2  Multiple sites                NaN
#
#   premises_address_2 premises_address_3 premises_suburb  \
# 0                NaN                NaN             NaN
# 1                NaN                NaN             NaN
# 2                NaN                NaN             NaN
# 3                NaN                NaN          ORANGE
# 4                NaN                NaN             NaN
#
#   premises_state_abbreviation  premises_post_code  latitude  longitude  \
# 0                         NSW                 NaN       NaN        NaN
# 1                         NSW                 NaN       NaN        NaN
# 2                         NSW                 NaN       NaN        NaN
# 3                         NSW              2800.0       NaN        NaN
# 4                         NSW                 NaN       NaN        NaN
#
#   the_geom
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %% [markdown]
# ### Clearing the dataset by dropping the na values since a lot of the columns contain the na values, I am not sure if there is any column is full of na values although it is unlikely.

# %%
f_polls = f_polls.drop(columns = ['FID'])
# the FID coloumn is not useful, and too long which affect the reading of the dataset, so this column is droped.
f_polls = f_polls.dropna(axis = 1, how = 'all')
# the line is to check if there is column with all entries being null, then drop the column.
f_polls
# Out:
#      state  division_id division_name  polling_place_id  \
# 0      NSW          104        Barton             33595
# 1      NSW          105     Bennelong             33596
# 2      NSW          107      Blaxland             33600
# 3      NSW          109        Calare             33603
# 4      NSW          113        Cowper             33716
# ...    ...          ...           ...               ...
# 2925   NSW          150       Whitlam              2809
# 2926   NSW          150       Whitlam             58798
# 2927   NSW          150       Whitlam             31242
# 2928   NSW          150       Whitlam               564
# 2929   NSW          150       Whitlam             58667
#
#       polling_place_type_id       polling_place_name          premises_name  \
# 0                         2  Special Hospital Team 1         Multiple sites
# 1                         2  Special Hospital Team 1         Multiple sites
# 2                         2  Special Hospital Team 1         Multiple sites
# 3                         2  Special Hospital Team 1         Multiple sites
# 4                         2  Special Hospital Team 2         Multiple sites
# ...                     ...                      ...                    ...
# 2925                      1            Warilla South    Warilla High School
# 2926                      5     Warilla WHITLAM PPVC  2/144 Shellharbour Rd
# 2927                      1                    Welby   Welby Community Hall
# 2928                      1                  Windang  Windang Public School
# 2929                      5  Wollongong WHITLAM PPVC          3/51 Crown St
#
#       premises_address_1 premises_address_2 premises_address_3  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 2925       10 Keross Ave                NaN                NaN
# 2926                 NaN                NaN                NaN
# 2927  14 Currockbilly St                NaN                NaN
# 2928   60-64 Oakland Ave                NaN                NaN
# 2929                 NaN                NaN                NaN
#
#       premises_suburb premises_state_abbreviation  premises_post_code  \
# 0                 NaN                         NSW                 NaN
# 1                 NaN                         NSW                 NaN
# 2                 NaN                         NSW                 NaN
# 3              ORANGE                         NSW              2800.0
# 4                 NaN                         NSW                 NaN
# ...               ...                         ...                 ...
# 2925  BARRACK HEIGHTS                         NSW              2528.0
# 2926          WARILLA                         NSW              2528.0
# 2927            WELBY                         NSW              2575.0
# 2928          WINDANG                         NSW              2528.0
# 2929       WOLLONGONG                         NSW              2500.0
#
#        latitude   longitude                         the_geom
# 0           NaN         NaN                              NaN
# 1           NaN         NaN                              NaN
# 2           NaN         NaN                              NaN
# 3           NaN         NaN                              NaN
# 4           NaN         NaN                              NaN
# ...         ...         ...                              ...
# 2925 -34.564200  150.858000         POINT (-34.5642 150.858)
# 2926 -34.550823  150.859755  POINT (-34.5508228 150.8597546)
# 2927 -34.440900  150.424000         POINT (-34.4409 150.424)
# 2928 -34.531600  150.866000         POINT (-34.5316 150.866)
# 2929        NaN         NaN                              NaN
#
# [2930 rows x 16 columns]

# %% [markdown]
# ### Filtering the dataset as explained in the comments
# ### Since the premises suburb is picked as this column contains less na values by looking at the database (ensuring the sufficient size of our dataset) and it is a region instead of a specific place which probably enables more details to analyse.
# ### the 'the_geom' column was dropped due to its geometry has the coordinate with latitude as x and longtitude as y which is not corresponding to the geometry type POINT that we are using. The new geometry column 'geom' will be created.
# ### After the filtering process, if there is any na value in the row, the row is dropped since the row is not informative. The previous step is to ensure there is no one column that contain all entries as na.

# %%
f_polls2 = f_polls[['state', 'division_name', 'polling_place_id', 'premises_suburb', 'latitude', 'longitude']]
# only these columns are kepted because they can make connection with other database we obtained, especially based on the geometry column.
f_polls2 = f_polls2[f_polls2['state'] == 'NSW']
# SA2 database filter down to Greater Sydney which is within NSW, so ensure the relevance between all the databases we obtained.
f_polls2 = f_polls2.drop(columns = "state")
# as the previous line ensure the state is NSW, so this column can be dropped.
f_polls2 = f_polls2.dropna()
# to drop rows with na values in the dataset
# f_polls2['geom'] = f_polls2['geom'].apply(lambda x: WKTElement(x.wkt, srid=SRID))
# f_polls2

# %%
f_polls2.head()
# Out:
#    division_name  polling_place_id   premises_suburb  latitude   longitude
# 13         Banks                58            OATLEY -33.98470  151.081000
# 15       Chifley               392           DHARRUK -33.74750  150.817000
# 16         Banks                31           ALLAWAH -33.97679  151.114897
# 17         Banks                67  SOUTH HURSTVILLE -33.97560  151.111000
# 18         Banks             56500     BEVERLY HILLS -33.94130  151.075000

# %%
f_polls2['geom'] = gpd.points_from_xy(f_polls2.longitude, f_polls2.latitude)  # creating the geometry column
f_polls2 = f_polls2.drop(columns=['latitude', 'longitude'])  # removing the old latitude/longitude fields
f_polls2.head()
# Out:
#    division_name  polling_place_id   premises_suburb  \
# 13         Banks                58            OATLEY
# 15       Chifley               392           DHARRUK
# 16         Banks                31           ALLAWAH
# 17         Banks                67  SOUTH HURSTVILLE
# 18         Banks             56500     BEVERLY HILLS
#
#                            geom
# 13  POINT (151.08100 -33.98470)
# 15  POINT (150.81700 -33.74750)
# 16  POINT (151.11490 -33.97679)
# 17  POINT (151.11100 -33.97560)
# 18  POINT (151.07500 -33.94130)

# %%
f_polls2 = gpd.GeoDataFrame(f_polls2, geometry = 'geom')
f_polls2 = f_polls2.set_crs('epsg:4283')
f_polls2.to_crs(GDA2020, inplace = True)

# %%
f_polls2.crs.name
# Out:
# 'GDA2020'

# %%
f_polls2['geom'] = f_polls2['geom'].apply(lambda x: WKTElement(x.wkt, srid=GDA2020))
# ensure the spatial data type from geopandas are the same as the geopandas type in sql
f_polls2
# Out:
# /var/folders/1c/25dx1kl527z_bk2pgcg8jspc0000gn/T/ipykernel_63889/3305661695.py:1: UserWarning: Geometry column does not contain geometry.
#   f_polls2['geom'] = f_polls2['geom'].apply(lambda x: WKTElement(x.wkt, srid=GDA2020))
#      division_name  polling_place_id   premises_suburb  \
# 13           Banks                58            OATLEY
# 15         Chifley               392           DHARRUK
# 16           Banks                31           ALLAWAH
# 17           Banks                67  SOUTH HURSTVILLE
# 18           Banks             56500     BEVERLY HILLS
# ...            ...               ...               ...
# 2924       Whitlam              2810           WARILLA
# 2925       Whitlam              2809   BARRACK HEIGHTS
# 2926       Whitlam             58798           WARILLA
# 2927       Whitlam             31242             WELBY
# 2928       Whitlam               564           WINDANG
#
#                                                 geom
# 13    POINT (151.08100543267227 -33.984687305721565)
# 15     POINT (150.81700550198053 -33.74748727967633)
# 16      POINT (151.1149028288584 -33.97677700881712)
# 17       POINT (151.111005429578 -33.97558730844629)
# 18      POINT (151.0750054393399 -33.94128730486068)
# ...                                              ...
# 2924   POINT (150.85177539059526 -34.54722728844072)
# 2925  POINT (150.85800538739764 -34.564187289130984)
# 2926   POINT (150.85975998893758 -34.55081008920011)
# 2927   POINT (150.42400546771734 -34.44088724871808)
# 2928   POINT (150.8660053906017 -34.531587289642175)
#
# [2790 rows x 4 columns]

# %% [markdown]
# ### Create the corresponding table in the SQL server and insert the database content into the table so that we can access the database through SQL queries.

# %%
conn.execute(text("""
drop table if exists polls CASCADE;
create table polls (
    division_name VARCHAR(100),
    polling_place_id numeric PRIMARY KEY,
    premises_suburb VARCHAR(100),
    geom GEOMETRY(POINT, 7844)
);"""
))

f_polls2.to_sql('polls', conn, if_exists = 'replace', index = False, 
                dtype={'geom': Geometry('POINT', GDA2020)})
query(conn, "select * from polls")
# Out:
#      division_name  polling_place_id   premises_suburb  \
# 0            Banks                58            OATLEY
# 1          Chifley               392           DHARRUK
# 2            Banks                31           ALLAWAH
# 3            Banks                67  SOUTH HURSTVILLE
# 4            Banks             56500     BEVERLY HILLS
# ...            ...               ...               ...
# 2785       Whitlam              2810           WARILLA
# 2786       Whitlam              2809   BARRACK HEIGHTS
# 2787       Whitlam             58798           WARILLA
# 2788       Whitlam             31242             WELBY
# 2789       Whitlam               564           WINDANG
#
#                                                    geom
# 0     0101000020A41E00000684B49897E26240246ECF3B0AFE...
# 1     0101000020A41E000012F5B8E824DA62406331C6A9ADDF...
# 2     0101000020A41E00004585B248ADE36240582D6E0707FD...
# 3     0101000020A41E0000E936425B8DE36240B215800BE0FC...
# 4     0101000020A41E0000959FCE7166E262402042371A7CF8...
# ...                                                 ...
# 2785  0101000020A41E00009EC476BE41DB624074AA358B0B46...
# 2786  0101000020A41E000045D5B6C774DB624078D1014A3748...
# 2787  0101000020A41E0000AE5C612783DB6240EEB5EBF18046...
# 2788  0101000020A41E00007A25EA7391CD6240D93B4DFE6E38...
# 2789  0101000020A41E000069D9EF50B6DB6240C0FD630D0B44...
#
# [2790 rows x 4 columns]

# %% [markdown]
# # The below is the Population dataset.

# %% [markdown]
# ### Population dataset is also a csv file so using read_csv function in pandas library to transform this database into a dataframe.

# %%
f_population = pd.read_csv('Population.csv')
f_population
# Out:
#       sa2_code                     sa2_name  0-4_people  5-9_people  \
# 0    102011028     Avoca Beach - Copacabana         424         522
# 1    102011029  Box Head - MacMasters Beach         511         666
# 2    102011030              Calga - Kulnura         200         225
# 3    102011031          Erina - Green Point         683         804
# 4    102011032        Gosford - Springfield        1164        1044
# ..         ...                          ...         ...         ...
# 368  128021537          Royal National Park           2           4
# 369  128021538        Sutherland - Kirrawee        1519        1292
# 370  128021607                     Engadine        1157        1283
# 371  128021608         Loftus - Yarrawarrah         503         487
# 372  128021609             Woronora Heights         166         217
#
#      10-14_people  15-19_people  20-24_people  25-29_people  30-34_people  \
# 0             623           552           386           222           306
# 1             702           592           461           347           420
# 2             258           278           274           227           214
# 3             880           838           661           502           587
# 4            1084          1072          1499          1864          1750
# ..            ...           ...           ...           ...           ...
# 368            10             4             9             7             1
# 369          1150          1117          1335          1852          2120
# 370          1469          1209           891           675           928
# 371           575           508           380           293           426
# 372           272           310           240           153           123
#
#      35-39_people  ...  45-49_people  50-54_people  55-59_people  \
# 0             416  ...           572           602           570
# 1             535  ...           749           749           794
# 2             286  ...           325           436           422
# 3             757  ...           859           882           901
# 4            1520  ...          1330          1241          1377
# ..            ...  ...           ...           ...           ...
# 368             2  ...             4             0             0
# 369          1945  ...          1569          1391          1285
# 370          1229  ...          1315          1086           909
# 371           493  ...           564           477           450
# 372           161  ...           303           316           295
#
#      60-64_people  65-69_people  70-74_people  75-79_people  80-84_people  \
# 0             520           464           369           226           142
# 1             895           863           925           603           331
# 2             397           327           264           190           100
# 3             930           917          1065           976           773
# 4            1285          1166           949           664           476
# ..            ...           ...           ...           ...           ...
# 368             0             1             0             0             0
# 369          1157           909           909           781           582
# 370           764           707           886           748           389
# 371           387           418           335           263           192
# 372           310           217           143            80            30
#
#      85-and-over_people  total_people
# 0                    70          7530
# 1                   264         11052
# 2                    75          4748
# 3                  1028         14803
# 4                   537         21346
# ..                  ...           ...
# 368                   0            45
# 369                 807         23369
# 370                 327         17379
# 371                 109          7354
# 372                  16          3551
#
# [373 rows x 21 columns]

# %% [markdown]
# ### The below is to clean the data to ensure the total number of people is at least 100 as if the region with too less people, the information it could provide is limited.

# %%
f_population_all = f_population[f_population['total_people'] >= 100]
f_population_all = f_population[['sa2_code', 'sa2_name', 'total_people']]
f_population_all['sa2_code']=f_population_all['sa2_code'].apply(int)
# Out:
# /var/folders/1c/25dx1kl527z_bk2pgcg8jspc0000gn/T/ipykernel_63889/1891065897.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f_population_all['sa2_code']=f_population_all['sa2_code'].apply(int)

# %% [markdown]
# ### Another dataframe is created but this time only young people is obtained and the region has at least 100 young people. Since young people represents the vital force and future of a region, I think this database might be useful.

# %%
f_population_young = f_population[['sa2_code', 'sa2_name', '0-4_people', '5-9_people', '10-14_people', '15-19_people']]
f_population_young_sum = {'sa2_code': f_population_young['sa2_code'], 'sa2_name': f_population_young['sa2_name'], 
                          'total_young_people' : f_population_young['0-4_people'] + f_population_young['5-9_people'] + f_population_young['10-14_people'] + f_population_young['15-19_people']}
f_population_young_sum = pd.DataFrame(f_population_young_sum)

# %% [markdown]
# ### The below ensure all the people are young people and the total number of young people is at least 100 with a similar reason as above.

# %%
f_population_young_sum2 = f_population_young_sum[f_population_young_sum['total_young_people'] >= 100]
f_population_young_sum2
# Out:
#       sa2_code                     sa2_name  total_young_people
# 0    102011028     Avoca Beach - Copacabana                2121
# 1    102011029  Box Head - MacMasters Beach                2471
# 2    102011030              Calga - Kulnura                 961
# 3    102011031          Erina - Green Point                3205
# 4    102011032        Gosford - Springfield                4364
# ..         ...                          ...                 ...
# 367  128021536  Oyster Bay - Como - Jannali                6212
# 369  128021538        Sutherland - Kirrawee                5078
# 370  128021607                     Engadine                5118
# 371  128021608         Loftus - Yarrawarrah                2073
# 372  128021609             Woronora Heights                 965
#
# [359 rows x 3 columns]

# %% [markdown]
# ### Create the two corresponding tables in the SQL server and insert the database content into these two corresponding tables so that we can access the database through SQL queries.

# %%
conn.execute(text("""
drop table if exists population_young cascade;
create table population_young (
    id INT PRIMARY KEY,
    sa2_code numeric,
    sa2_name VARCHAR(100),
    total_young_people integer
);"""))

conn.execute(text("""
drop table if exists population;
create table population (
    id INT PRIMARY KEY,
    sa2_code numeric,
    sa2_name VARCHAR(100),
    total_people integer
);"""))

f_population_all.to_sql('population', conn, if_exists = 'replace', index = False)
query(conn, "select * from population")

f_population_young_sum2.to_sql('population_young', conn, if_exists = 'replace', index = False)
query(conn, "select * from population_young").info
# Out:
# <bound method DataFrame.info of       sa2_code                     sa2_name  total_young_people
# 0    102011028     Avoca Beach - Copacabana                2121
# 1    102011029  Box Head - MacMasters Beach                2471
# 2    102011030              Calga - Kulnura                 961
# 3    102011031          Erina - Green Point                3205
# 4    102011032        Gosford - Springfield                4364
# ..         ...                          ...                 ...
# 354  128021536  Oyster Bay - Como - Jannali                6212
# 355  128021538        Sutherland - Kirrawee                5078
# 356  128021607                     Engadine                5118
# 357  128021608         Loftus - Yarrawarrah                2073
# 358  128021609             Woronora Heights                 965
#
# [359 rows x 3 columns]>

# %% [markdown]
# # The below is the Stops dataset.

# %% [markdown]
# ### The Stop database is in the format of txt but since read_csv can deal with this format, so read_csv function in pandas library is used where the "sep" parameter enables the content in the txt file can be separated into columns if there is a comma.

# %%
f_stops = pd.read_csv('Stops.txt', sep=',')
f_stops
# Out:
#         stop_id  stop_code                             stop_name   stop_lat  \
# 0        200039   200039.0     Central Station, Eddy Av, Stand A -33.882206
# 1        200054   200054.0     Central Station, Eddy Av, Stand D -33.882042
# 2        200060        NaN                       Central Station -33.884084
# 3        201510        NaN                       Redfern Station -33.891690
# 4        201646   201646.0  Redfern Station, Gibbons St, Stand B -33.893329
# ...         ...        ...                                   ...        ...
# 114713   212753   212753.0     Sydney Olympic Park Wharf, Side B -33.822016
# 114714  2137185  2137185.0                Cabarita Wharf, Side A -33.840669
# 114715  2137186  2137186.0                Cabarita Wharf, Side B -33.840769
# 114716    21501    21501.0                      Parramatta Wharf -33.813904
# 114717  2150112        NaN                      Parramatta Wharf -33.813952
#
#           stop_lon  location_type parent_station  wheelchair_boarding  \
# 0       151.206665            NaN         200060                    0
# 1       151.206991            NaN         200060                    0
# 2       151.206292            1.0            NaN                    0
# 3       151.198866            1.0            NaN                    0
# 4       151.198882            NaN         201510                    0
# ...            ...            ...            ...                  ...
# 114713  151.078797            NaN          21271                    1
# 114714  151.116926            NaN          21371                    1
# 114715  151.116899            NaN          21371                    1
# 114716  151.010577            NaN        2150112                    1
# 114717  151.010482            1.0            NaN                    1
#
#        platform_code
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 114713             B
# 114714            1A
# 114715            1B
# 114716           NaN
# 114717           NaN
#
# [114718 rows x 9 columns]

# %% [markdown]
# ### Cleaning the dataset based on the relevance between it with our other database.

# %%
f_stops = f_stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon', 'wheelchair_boarding']]
f_stops = f_stops.dropna().drop_duplicates().sort_values(['wheelchair_boarding'])
f_stops
# Out:
#        stop_id                             stop_name   stop_lat    stop_lon  \
# 0       200039     Central Station, Eddy Av, Stand A -33.882206  151.206665
# 76335   239027             Nandewar St At Fitzroy St -30.330193  149.790800
# 76334   239026  Narrabri Community Health, Barwan St -30.323138  149.783312
# 76333   239025               Doyle St At Maitland St -30.324823  149.782549
# 76332   239024             Woolworths, Tibbereena St -30.322658  149.780845
# ...        ...                                   ...        ...         ...
# 854    2284181           Teralba Station, Platform 1 -32.962449  151.603692
# 855    2284182           Teralba Station, Platform 2 -32.962388  151.603646
# 1088    277882          Woodford Station, Platform 2 -33.735658  150.481888
# 455    2114172         Denistone Station, Platform 2 -33.799649  151.087070
# 42642   246622                           Iluka Wharf -29.403870  153.346231
#
#        wheelchair_boarding
# 0                        0
# 76335                    0
# 76334                    0
# 76333                    0
# 76332                    0
# ...                    ...
# 854                      2
# 855                      2
# 1088                     2
# 455                      2
# 42642                    2
#
# [114718 rows x 5 columns]

# %% [markdown]
# ### Create the geometry column (which is a column in some of our other database) based on the latitude and longtitude column given in the database

# %%
f_stops['geom'] = gpd.points_from_xy(f_stops.stop_lon, f_stops.stop_lat)  # creating the geometry column
f_stops = f_stops.drop(columns=['stop_lat', 'stop_lon'])  # removing the old latitude/longitude fields
f_stops
# Out:
#        stop_id                             stop_name  wheelchair_boarding  \
# 0       200039     Central Station, Eddy Av, Stand A                    0
# 76335   239027             Nandewar St At Fitzroy St                    0
# 76334   239026  Narrabri Community Health, Barwan St                    0
# 76333   239025               Doyle St At Maitland St                    0
# 76332   239024             Woolworths, Tibbereena St                    0
# ...        ...                                   ...                  ...
# 854    2284181           Teralba Station, Platform 1                    2
# 855    2284182           Teralba Station, Platform 2                    2
# 1088    277882          Woodford Station, Platform 2                    2
# 455    2114172         Denistone Station, Platform 2                    2
# 42642   246622                           Iluka Wharf                    2
#
#                               geom
# 0      POINT (151.20666 -33.88221)
# 76335  POINT (149.79080 -30.33019)
# 76334  POINT (149.78331 -30.32314)
# 76333  POINT (149.78255 -30.32482)
# 76332  POINT (149.78084 -30.32266)
# ...                            ...
# 854    POINT (151.60369 -32.96245)
# 855    POINT (151.60365 -32.96239)
# 1088   POINT (150.48189 -33.73566)
# 455    POINT (151.08707 -33.79965)
# 42642  POINT (153.34623 -29.40387)
#
# [114718 rows x 4 columns]

# %%
f_stops = gpd.GeoDataFrame(f_stops, geometry = 'geom')
f_stops = f_stops.set_crs('epsg:7844')
f_stops.crs.name
# Out:
# 'GDA2020'

# %% [markdown]
# ### The WKTElement from geoalchemy2 library is used to ensure the geometry type in the 'geom' column consistent with the geometry type in PostGIS by converting the data to the Well_Known Text (WKT) format.

# %%
f_stops['geom'] = f_stops['geom'].apply(lambda x: WKTElement(x.wkt, srid=GDA2020))
f_stops
# Out:
# /var/folders/1c/25dx1kl527z_bk2pgcg8jspc0000gn/T/ipykernel_63889/2332732185.py:1: UserWarning: Geometry column does not contain geometry.
#   f_stops['geom'] = f_stops['geom'].apply(lambda x: WKTElement(x.wkt, srid=GDA2020))
#        stop_id                             stop_name  wheelchair_boarding  \
# 0       200039     Central Station, Eddy Av, Stand A                    0
# 76335   239027             Nandewar St At Fitzroy St                    0
# 76334   239026  Narrabri Community Health, Barwan St                    0
# 76333   239025               Doyle St At Maitland St                    0
# 76332   239024             Woolworths, Tibbereena St                    0
# ...        ...                                   ...                  ...
# 854    2284181           Teralba Station, Platform 1                    2
# 855    2284182           Teralba Station, Platform 2                    2
# 1088    277882          Woodford Station, Platform 2                    2
# 455    2114172         Denistone Station, Platform 2                    2
# 42642   246622                           Iluka Wharf                    2
#
#                                              geom
# 0       POINT (151.20666465471 -33.8822064874687)
# 76335   POINT (149.79079974311 -30.3301934731436)
# 76334  POINT (149.783311889044 -30.3231380290087)
# 76333  POINT (149.782548646872 -30.3248227779972)
# 76332   POINT (149.78084484497 -30.3226584220644)
# ...                                           ...
# 854     POINT (151.60369176421 -32.9624489712119)
# 855    POINT (151.603645830589 -32.9623876082877)
# 1088   POINT (150.481887532685 -33.7356582884296)
# 455    POINT (151.087069616849 -33.7996485940745)
# 42642  POINT (153.346231103096 -29.4038700344653)
#
# [114718 rows x 4 columns]

# %% [markdown]
# ### Create the two corresponding table in the SQL server and insert the database content into the table so that we can access the database through SQL queries.

# %%
conn.execute(text("""
drop table if exists stops cascade;
create table stops (
    stop_id varchar(10) PRIMARY KEY,
    stop_name varchar(100),
    wheelchair_boarding integer,
    geom GEOMETRY(POINT,7844)
);"""))

f_stops.to_sql('stops', conn, if_exists = 'replace', index = False, dtype={'geom': Geometry('POINT', GDA2020)})
query(conn, "select * from stops")
# Out:
#         stop_id                             stop_name  wheelchair_boarding  \
# 0        200039     Central Station, Eddy Av, Stand A                    0
# 1        239027             Nandewar St At Fitzroy St                    0
# 2        239026  Narrabri Community Health, Barwan St                    0
# 3        239025               Doyle St At Maitland St                    0
# 4        239024             Woolworths, Tibbereena St                    0
# ...         ...                                   ...                  ...
# 114713  2284181           Teralba Station, Platform 1                    2
# 114714  2284182           Teralba Station, Platform 2                    2
# 114715   277882          Woodford Station, Platform 2                    2
# 114716  2114172         Denistone Station, Platform 2                    2
# 114717   246622                           Iluka Wharf                    2
#
#                                                      geom
# 0       0101000020A41E0000FFA631FF9CE66240A1FF6524ECF0...
# 1       0101000020A41E0000F74A433B4EB962402181388F8754...
# 2       0101000020A41E0000624018E410B96240AFAF822CB952...
# 3       0101000020A41E000004BB75A30AB962406C7EE8952753...
# 4       0101000020A41E0000AF0C54AEFCB86240AA8B0ABE9952...
# ...                                                   ...
# 114713  0101000020A41E0000B004647151F3624044B62387317B...
# 114714  0101000020A41E0000E3970F1151F36240EED563842F7B...
# 114715  0101000020A41E00006E27679F6BCF624011EB000D2ADE...
# 114716  0101000020A41E0000EF9A3846C9E26240D2EB97E25AE6...
# 114717  0101000020A41E0000F8144053142B6340E4DCCD066467...
#
# [114718 rows x 4 columns]

# %% [markdown]
# # The below is the Income dataset.

# %% [markdown]
# ### This is also a csv file so used read_csv function to access the dataframe.

# %%
f_income = pd.read_csv('Income.csv')
f_income
# Out:
#      sa2_code21                         sa2_name earners median_age  \
# 0     101021007                        Braidwood    2467         51
# 1     101021008                          Karabar    5103         42
# 2     101021009                       Queanbeyan    7028         39
# 3     101021010                Queanbeyan - East    3398         39
# 4     101021012  Queanbeyan West - Jerrabomberra    8422         44
# ..          ...                              ...     ...        ...
# 637   128021537              Royal National Park      14         37
# 638   128021538            Sutherland - Kirrawee   13895         41
# 639   128021607                         Engadine   10239         43
# 640   128021608             Loftus - Yarrawarrah    4424         45
# 641   128021609                 Woronora Heights    2491         47
#
#     median_income mean_income
# 0           46640       68904
# 1           65564       69672
# 2           63528       69174
# 3           66148       74162
# 4           78630       91981
# ..            ...         ...
# 637         36980       47584
# 638         64940       74867
# 639         63695       72995
# 640         63087       76440
# 641         65460       82717
#
# [642 rows x 6 columns]

# %% [markdown]
# ### By reading the database, np value has found which representing the missing value but cannot be detected by dropna() so the np values are first replace by the nah value in pandas system. Drop the row with the np value since the row is not informative.

# %%
f_income = f_income.replace('np', pd.NA)
f_income = f_income.dropna()
f_income = f_income.rename(columns={'sa2_code21':'sa2_code'})
f_income['sa2_code']=f_income['sa2_code'].apply(int)
f_income
# Out:
#       sa2_code                         sa2_name earners median_age  \
# 0    101021007                        Braidwood    2467         51
# 1    101021008                          Karabar    5103         42
# 2    101021009                       Queanbeyan    7028         39
# 3    101021010                Queanbeyan - East    3398         39
# 4    101021012  Queanbeyan West - Jerrabomberra    8422         44
# ..         ...                              ...     ...        ...
# 637  128021537              Royal National Park      14         37
# 638  128021538            Sutherland - Kirrawee   13895         41
# 639  128021607                         Engadine   10239         43
# 640  128021608             Loftus - Yarrawarrah    4424         45
# 641  128021609                 Woronora Heights    2491         47
#
#     median_income mean_income
# 0           46640       68904
# 1           65564       69672
# 2           63528       69174
# 3           66148       74162
# 4           78630       91981
# ..            ...         ...
# 637         36980       47584
# 638         64940       74867
# 639         63695       72995
# 640         63087       76440
# 641         65460       82717
#
# [635 rows x 6 columns]

# %% [markdown]
# ### Create the two corresponding table in the SQL server and insert the database content into the table so that we can access the database through SQL queries.

# %%
conn.execute(text("""
drop table if exists income cascade;
create table income(
    id INT PRIMARY KEY,
    sa2_code21 Numeric,
    sa2_name VARCHAR(100),
    earners Integer,
    median_age Integer,
    median_income Integer, 
    mean_income Integer
);"""))

f_income.to_sql('income', conn, if_exists='replace', index=False)
query(conn, "select * from income")
# Out:
#       sa2_code                         sa2_name earners median_age  \
# 0    101021007                        Braidwood    2467         51
# 1    101021008                          Karabar    5103         42
# 2    101021009                       Queanbeyan    7028         39
# 3    101021010                Queanbeyan - East    3398         39
# 4    101021012  Queanbeyan West - Jerrabomberra    8422         44
# ..         ...                              ...     ...        ...
# 630  128021537              Royal National Park      14         37
# 631  128021538            Sutherland - Kirrawee   13895         41
# 632  128021607                         Engadine   10239         43
# 633  128021608             Loftus - Yarrawarrah    4424         45
# 634  128021609                 Woronora Heights    2491         47
#
#     median_income mean_income
# 0           46640       68904
# 1           65564       69672
# 2           63528       69174
# 3           66148       74162
# 4           78630       91981
# ..            ...         ...
# 630         36980       47584
# 631         64940       74867
# 632         63695       72995
# 633         63087       76440
# 634         65460       82717
#
# [635 rows x 6 columns]

# %% [markdown]
# # ALL CURRENT DATABASE in sql

# %%
query(conn, "select * from sa2")
# Out:
#       sa2_code                     sa2_name  \
# 0    102011028     Avoca Beach - Copacabana
# 1    102011029  Box Head - MacMasters Beach
# 2    102011030              Calga - Kulnura
# 3    102011031          Erina - Green Point
# 4    102011032        Gosford - Springfield
# ..         ...                          ...
# 368  128021537          Royal National Park
# 369  128021538        Sutherland - Kirrawee
# 370  128021607                     Engadine
# 371  128021608         Loftus - Yarrawarrah
# 372  128021609             Woronora Heights
#
#                                                   geom
# 0    0106000020A41E0000010000000103000000010000005E...
# 1    0106000020A41E00000100000001030000000100000010...
# 2    0106000020A41E00000200000001030000000100000085...
# 3    0106000020A41E00000100000001030000000100000041...
# 4    0106000020A41E0000010000000103000000010000007E...
# ..                                                 ...
# 368  0106000020A41E00000100000001030000000100000046...
# 369  0106000020A41E00000100000001030000000100000089...
# 370  0106000020A41E0000010000000103000000010000008E...
# 371  0106000020A41E000001000000010300000001000000A1...
# 372  0106000020A41E000001000000010300000001000000F0...
#
# [373 rows x 3 columns]

# %%
query(conn, "select * from primary_school")
# Out:
#      use_id catch_type         use_desc  \
# 0      2838    PRIMARY       Parklea PS
# 1      2404    PRIMARY    Lindfield EPS
# 2      4393    PRIMARY  Carlingford WPS
# 3      4481    PRIMARY    St Andrews PS
# 4      4615    PRIMARY   Caddies Ck  PS
# ...     ...        ...              ...
# 1657   2409    PRIMARY      Lismore SPS
# 1658   4383    PRIMARY   E A Southee PS
# 1659   3275    PRIMARY    Tumbarumba PS
# 1660   2239    PRIMARY       Jindera PS
# 1661   3594    PRIMARY         Louth PS
#
#                                                    geom
# 0     0106000020A41E00000100000001030000000100000078...
# 1     0106000020A41E000001000000010300000001000000BE...
# 2     0106000020A41E00000100000001030000000100000065...
# 3     0106000020A41E00000100000001030000000100000040...
# 4     0106000020A41E00000100000001030000000100000056...
# ...                                                 ...
# 1657  0106000020A41E000001000000010300000001000000C9...
# 1658  0106000020A41E000001000000010300000001000000B9...
# 1659  0106000020A41E000001000000010300000001000000C0...
# 1660  0106000020A41E000001000000010300000001000000F6...
# 1661  0106000020A41E00000100000001030000000100000094...
#
# [1662 rows x 4 columns]

# %%
query(conn, "select * from secondary_school")
# Out:
#     use_id    catch_type         use_desc  \
# 0     8503     HIGH_COED     Billabong HS
# 1     8266     HIGH_COED  James Fallon HS
# 2     8559     HIGH_COED       Jamison HS
# 3     8502     HIGH_COED       Tomaree HS
# 4     8505     HIGH_COED        Murray HS
# ..     ...           ...              ...
# 431   8213     HIGH_BOYS      Birrong BHS
# 432   8108     HIGH_COED      Cessnock HS
# 433   3235  CENTRAL_HIGH     Tooleybuc CS
# 434   1115  CENTRAL_HIGH     Balranald CS
# 435   2213  CENTRAL_HIGH       Ivanhoe CS
#
#                                                   geom
# 0    0106000020A41E0000010000000103000000010000006D...
# 1    0106000020A41E00000100000001030000000100000071...
# 2    0106000020A41E0000010000000103000000020000002F...
# 3    0106000020A41E0000010000000103000000010000003B...
# 4    0106000020A41E0000010000000103000000010000003F...
# ..                                                 ...
# 431  0106000020A41E00000100000001030000000100000040...
# 432  0106000020A41E000001000000010300000001000000AD...
# 433  0106000020A41E0000010000000103000000010000003E...
# 434  0106000020A41E0000010000000103000000010000005B...
# 435  0106000020A41E00000100000001030000000100000068...
#
# [436 rows x 4 columns]

# %%
query(conn, "select * from business")
# Out:
#       industry_code                      industry_name   sa2_code  \
# 0                 A  Agriculture, Forestry and Fishing  101021007
# 1                 A  Agriculture, Forestry and Fishing  101021008
# 2                 A  Agriculture, Forestry and Fishing  101021009
# 3                 A  Agriculture, Forestry and Fishing  101021010
# 4                 A  Agriculture, Forestry and Fishing  101021012
# ...             ...                                ...        ...
# 12212             S                     Other Services  128021538
# 12213             S                     Other Services  128021607
# 12214             S                     Other Services  128021608
# 12215             S                     Other Services  128021609
# 12216             S                     Other Services  199999499
#
#                               sa2_name  turnover_value_under2m  all_businesses
# 0                            Braidwood                     291             296
# 1                              Karabar                       9               9
# 2                           Queanbeyan                      13              15
# 3                    Queanbeyan - East                       3               3
# 4      Queanbeyan West - Jerrabomberra                      16              16
# ...                                ...                     ...             ...
# 12212            Sutherland - Kirrawee                     145             152
# 12213                         Engadine                      85              87
# 12214             Loftus - Yarrawarrah                      20              22
# 12215                 Woronora Heights                       8               9
# 12216                Currently Unknown                     164             190
#
# [12217 rows x 6 columns]

# %%
query(conn, "select * from polls")
# Out:
#      division_name  polling_place_id   premises_suburb  \
# 0            Banks                58            OATLEY
# 1          Chifley               392           DHARRUK
# 2            Banks                31           ALLAWAH
# 3            Banks                67  SOUTH HURSTVILLE
# 4            Banks             56500     BEVERLY HILLS
# ...            ...               ...               ...
# 2785       Whitlam              2810           WARILLA
# 2786       Whitlam              2809   BARRACK HEIGHTS
# 2787       Whitlam             58798           WARILLA
# 2788       Whitlam             31242             WELBY
# 2789       Whitlam               564           WINDANG
#
#                                                    geom
# 0     0101000020A41E00000684B49897E26240246ECF3B0AFE...
# 1     0101000020A41E000012F5B8E824DA62406331C6A9ADDF...
# 2     0101000020A41E00004585B248ADE36240582D6E0707FD...
# 3     0101000020A41E0000E936425B8DE36240B215800BE0FC...
# 4     0101000020A41E0000959FCE7166E262402042371A7CF8...
# ...                                                 ...
# 2785  0101000020A41E00009EC476BE41DB624074AA358B0B46...
# 2786  0101000020A41E000045D5B6C774DB624078D1014A3748...
# 2787  0101000020A41E0000AE5C612783DB6240EEB5EBF18046...
# 2788  0101000020A41E00007A25EA7391CD6240D93B4DFE6E38...
# 2789  0101000020A41E000069D9EF50B6DB6240C0FD630D0B44...
#
# [2790 rows x 4 columns]

# %%
query(conn, "select * from population")
# Out:
#       sa2_code                     sa2_name  total_people
# 0    102011028     Avoca Beach - Copacabana          7530
# 1    102011029  Box Head - MacMasters Beach         11052
# 2    102011030              Calga - Kulnura          4748
# 3    102011031          Erina - Green Point         14803
# 4    102011032        Gosford - Springfield         21346
# ..         ...                          ...           ...
# 368  128021537          Royal National Park            45
# 369  128021538        Sutherland - Kirrawee         23369
# 370  128021607                     Engadine         17379
# 371  128021608         Loftus - Yarrawarrah          7354
# 372  128021609             Woronora Heights          3551
#
# [373 rows x 3 columns]

# %%
query(conn, "select * from population_young")
# Out:
#       sa2_code                     sa2_name  total_young_people
# 0    102011028     Avoca Beach - Copacabana                2121
# 1    102011029  Box Head - MacMasters Beach                2471
# 2    102011030              Calga - Kulnura                 961
# 3    102011031          Erina - Green Point                3205
# 4    102011032        Gosford - Springfield                4364
# ..         ...                          ...                 ...
# 354  128021536  Oyster Bay - Como - Jannali                6212
# 355  128021538        Sutherland - Kirrawee                5078
# 356  128021607                     Engadine                5118
# 357  128021608         Loftus - Yarrawarrah                2073
# 358  128021609             Woronora Heights                 965
#
# [359 rows x 3 columns]

# %%
query(conn, "select * from stops")
# Out:
#         stop_id                             stop_name  wheelchair_boarding  \
# 0        200039     Central Station, Eddy Av, Stand A                    0
# 1        239027             Nandewar St At Fitzroy St                    0
# 2        239026  Narrabri Community Health, Barwan St                    0
# 3        239025               Doyle St At Maitland St                    0
# 4        239024             Woolworths, Tibbereena St                    0
# ...         ...                                   ...                  ...
# 114713  2284181           Teralba Station, Platform 1                    2
# 114714  2284182           Teralba Station, Platform 2                    2
# 114715   277882          Woodford Station, Platform 2                    2
# 114716  2114172         Denistone Station, Platform 2                    2
# 114717   246622                           Iluka Wharf                    2
#
#                                                      geom
# 0       0101000020A41E0000FFA631FF9CE66240A1FF6524ECF0...
# 1       0101000020A41E0000F74A433B4EB962402181388F8754...
# 2       0101000020A41E0000624018E410B96240AFAF822CB952...
# 3       0101000020A41E000004BB75A30AB962406C7EE8952753...
# 4       0101000020A41E0000AF0C54AEFCB86240AA8B0ABE9952...
# ...                                                   ...
# 114713  0101000020A41E0000B004647151F3624044B62387317B...
# 114714  0101000020A41E0000E3970F1151F36240EED563842F7B...
# 114715  0101000020A41E00006E27679F6BCF624011EB000D2ADE...
# 114716  0101000020A41E0000EF9A3846C9E26240D2EB97E25AE6...
# 114717  0101000020A41E0000F8144053142B6340E4DCCD066467...
#
# [114718 rows x 4 columns]

# %%
query(conn, "select * from income")
# Out:
#       sa2_code                         sa2_name earners median_age  \
# 0    101021007                        Braidwood    2467         51
# 1    101021008                          Karabar    5103         42
# 2    101021009                       Queanbeyan    7028         39
# 3    101021010                Queanbeyan - East    3398         39
# 4    101021012  Queanbeyan West - Jerrabomberra    8422         44
# ..         ...                              ...     ...        ...
# 630  128021537              Royal National Park      14         37
# 631  128021538            Sutherland - Kirrawee   13895         41
# 632  128021607                         Engadine   10239         43
# 633  128021608             Loftus - Yarrawarrah    4424         45
# 634  128021609                 Woronora Heights    2491         47
#
#     median_income mean_income
# 0           46640       68904
# 1           65564       69672
# 2           63528       69174
# 3           66148       74162
# 4           78630       91981
# ..            ...         ...
# 630         36980       47584
# 631         64940       74867
# 632         63695       72995
# 633         63087       76440
# 634         65460       82717
#
# [635 rows x 6 columns]

# %% [markdown]
# ### merge the school dataset to provide the full school dataset loading

# %%
primary_df = query(conn, "select * from primary_school")
secondary_df = query(conn, "select * from secondary_school")

# %%
merged_school_df = pd.concat([primary_df, secondary_df])
merged_school_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2098 entries, 0 to 435
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   use_id      2098 non-null   object
#  1   catch_type  2098 non-null   object
#  2   use_desc    2098 non-null   object
#  3   geom        2098 non-null   object
# dtypes: object(4)
# memory usage: 82.0+ KB

# %%
all_school_df = merged_school_df.drop_duplicates(subset=['geom', 'use_id'], keep='first')
all_school_df.columns = all_school_df.columns.str.lower()

# %%
conn.execute(text("""
DROP TABLE IF EXISTS all_school;
CREATE TABLE all_school (
    USE_ID integer Primary Key,
    CATCH_TYPE VARCHAR(10),
    USED_DESC VARCHAR(100),
    geom GEOMETRY(MULTIPOLYGON,7844)
);"""
))
all_school_df.to_sql('all_school', conn, if_exists='replace', index=False)
query(conn, "select * from all_school")
# Out:
#      use_id    catch_type         use_desc  \
# 0      2838       PRIMARY       Parklea PS
# 1      2404       PRIMARY    Lindfield EPS
# 2      4393       PRIMARY  Carlingford WPS
# 3      4481       PRIMARY    St Andrews PS
# 4      4615       PRIMARY   Caddies Ck  PS
# ...     ...           ...              ...
# 2064   8593     HIGH_COED     Vincentia HS
# 2065   8213     HIGH_BOYS      Birrong BHS
# 2066   8108     HIGH_COED      Cessnock HS
# 2067   1115  CENTRAL_HIGH     Balranald CS
# 2068   2213  CENTRAL_HIGH       Ivanhoe CS
#
#                                                    geom
# 0     0106000020A41E00000100000001030000000100000078...
# 1     0106000020A41E000001000000010300000001000000BE...
# 2     0106000020A41E00000100000001030000000100000065...
# 3     0106000020A41E00000100000001030000000100000040...
# 4     0106000020A41E00000100000001030000000100000056...
# ...                                                 ...
# 2064  0106000020A41E000001000000010300000001000000E1...
# 2065  0106000020A41E00000100000001030000000100000040...
# 2066  0106000020A41E000001000000010300000001000000AD...
# 2067  0106000020A41E0000010000000103000000010000005B...
# 2068  0106000020A41E00000100000001030000000100000068...
#
# [2069 rows x 4 columns]

# %% [markdown]
# ## Merge datasets in SQL server

# %%
conn.execute(text("""DROP VIEW IF EXISTS selected_businesses_per_1000 CASCADE;
CREATE VIEW selected_businesses_per_1000 AS (
    SELECT 
        business.sa2_code,
        SUM(all_businesses) * 1000.0 / COALESCE(population.total_people, 1) AS total_businesses
    FROM 
        business
        LEFT JOIN population ON business.sa2_code = population.sa2_code
    WHERE 
        industry_name IN ('Agriculture, Forestry and Fishing', 'Mining', 'Manufacturing', 'Construction', 'Wholesale Trade', 'Retail Trade', 'Accommodation and Food Services', 'Transport, Postal and Warehousing', 'Financial and Insurance Services', 'Professional, Scientific and Technical Services', 'Education and Training', 'Health Care and Social Assistance', 'Arts and Recreation Services')
        AND population.total_people > 0
    GROUP BY 
        business.sa2_code, population.total_people
);"""))

# %%
query(conn, """select * from selected_businesses_per_1000""")
# Out:
#       sa2_code  total_businesses
# 0    120011386         94.290204
# 1    128011530         94.852906
# 2    128021533         48.353293
# 3    102021046         37.494892
# 4    119021663        116.820938
# ..         ...               ...
# 367  123011702         37.322769
# 368  119031373         59.632239
# 369  122011419        108.764520
# 370  123011433         77.765279
# 371  102011031         95.926501
#
# [372 rows x 2 columns]

# %%
conn.execute(text("""DROP VIEW IF EXISTS stops_per_sqkm;
CREATE VIEW stops_per_sqkm AS
SELECT sa2.sa2_code, ROUND(COUNT(stops.stop_id) / (ST_Area(sa2.geom) / 1000000.0)) AS stops_per_sqkm
FROM sa2
LEFT JOIN stops ON ST_Contains(sa2.geom, stops.geom)
GROUP BY sa2.sa2_code, sa2.geom;
"""))

# %%
query(conn, """select * from stops_per_sqkm""")
# Out:
#       sa2_code  stops_per_sqkm
# 0    122031694    3.869349e+11
# 1    122031696    1.385307e+11
# 2    123021703    4.077665e+10
# 3    117011321    2.032452e+11
# 4    125011587    3.332188e+11
# ..         ...             ...
# 368  125011583    3.917174e+11
# 369  124031461    2.255882e+11
# 370  115041301    3.427082e+10
# 371  123011699    1.124057e+11
# 372  121031407    1.699279e+11
#
# [373 rows x 2 columns]

# %%
conn.execute(text("""DROP VIEW IF EXISTS polls_per_sqkm;
CREATE VIEW polls_per_sqkm AS
SELECT sa2.sa2_code, COUNT(polls.polling_place_id)/ (ST_Area(sa2.geom) / 1000000.0) AS polls_per_sqkm
FROM sa2 LEFT JOIN polls ON ST_Contains(sa2.geom, polls.geom)
GROUP BY sa2.sa2_code, sa2.geom;"""))

# %%
query(conn, "select * from polls_per_sqkm")
# Out:
#       sa2_code  polls_per_sqkm
# 0    122031694    5.159132e+09
# 1    122031696    4.309843e+09
# 2    123021703    1.315376e+09
# 3    117011321    8.966702e+09
# 4    125011587    1.009754e+10
# ..         ...             ...
# 368  125011583    1.468940e+10
# 369  124031461    5.696672e+09
# 370  115041301    6.393810e+08
# 371  123011699    2.007245e+09
# 372  121031407    2.641367e+09
#
# [373 rows x 2 columns]

# %%
conn.execute(text("""DROP VIEW IF EXISTS schools_per_1000_young;
    CREATE VIEW schools_per_1000_young AS
SELECT sa2.sa2_code, COUNT(all_school.use_id) * 1000.0 / population_young.total_young_people AS schools_per_1000_young
FROM sa2
LEFT JOIN all_school ON ST_Contains(sa2.geom, all_school.geom)
JOIN population_young ON sa2.sa2_code = population_young.sa2_code
GROUP BY sa2.sa2_code,population_young.total_young_people;"""))

# %%
query(conn, """select * from schools_per_1000_young""")
# Out:
#       sa2_code  schools_per_1000_young
# 0    102011028                0.000000
# 1    102011029                0.000000
# 2    102011030                1.040583
# 3    102011031                0.000000
# 4    102011032                0.000000
# ..         ...                     ...
# 354  128021536                0.000000
# 355  128021538                0.393856
# 356  128021607                0.000000
# 357  128021608                0.000000
# 358  128021609                0.000000
#
# [359 rows x 2 columns]

# %% [markdown]
# # TASK 2 Computing z-score

# %%
conn.execute(text(""" DROP VIEW IF EXISTS sa2_metrics;
CREATE VIEW sa2_metrics AS
SELECT 
    sa2.sa2_code,
    sa2.sa2_name,
    geom,
    COALESCE(selected_businesses_per_1000.total_businesses, 0) AS businesses_per_1000,
    COALESCE(stops_per_sqkm.stops_per_sqkm, 0) AS stops_per_sqkm,
    COALESCE(polls_per_sqkm.polls_per_sqkm, 0) AS polls_per_sqkm,
    COALESCE(schools_per_1000_young.schools_per_1000_young, 0) AS schools_per_1000_young
FROM sa2
LEFT JOIN selected_businesses_per_1000 ON sa2.sa2_code = selected_businesses_per_1000.sa2_code
LEFT JOIN stops_per_sqkm ON sa2.sa2_code = stops_per_sqkm.sa2_code
LEFT JOIN polls_per_sqkm ON sa2.sa2_code = polls_per_sqkm.sa2_code
LEFT JOIN schools_per_1000_young ON sa2.sa2_code = schools_per_1000_young.sa2_code
WHERE sa2.sa2_code IN (
    SELECT sa2_code
    FROM population
    WHERE total_people >= 100
);"""))

# %%
sa2_region_info = query(conn, """select * from sa2_metrics""")

# %%
sa2_region_info
# Out:
#       sa2_code                     sa2_name  \
# 0    102011028     Avoca Beach - Copacabana
# 1    102011029  Box Head - MacMasters Beach
# 2    102011030              Calga - Kulnura
# 3    102011031          Erina - Green Point
# 4    102011032        Gosford - Springfield
# ..         ...                          ...
# 355  128021536  Oyster Bay - Como - Jannali
# 356  128021538        Sutherland - Kirrawee
# 357  128021607                     Engadine
# 358  128021608         Loftus - Yarrawarrah
# 359  128021609             Woronora Heights
#
#                                                   geom  businesses_per_1000  \
# 0    0106000020A41E0000010000000103000000010000005E...            83.001328
# 1    0106000020A41E00000100000001030000000100000010...            70.484980
# 2    0106000020A41E00000200000001030000000100000085...           198.188711
# 3    0106000020A41E00000100000001030000000100000041...            95.926501
# 4    0106000020A41E0000010000000103000000010000007E...            85.261876
# ..                                                 ...                  ...
# 355  0106000020A41E000001000000010300000001000000EF...            55.392533
# 356  0106000020A41E00000100000001030000000100000089...            70.477984
# 357  0106000020A41E0000010000000103000000010000008E...            49.542551
# 358  0106000020A41E000001000000010300000001000000A1...            50.176775
# 359  0106000020A41E000001000000010300000001000000F0...            54.632498
#
#      stops_per_sqkm  polls_per_sqkm  schools_per_1000_young
# 0      2.033888e+11    3.202973e+09                0.000000
# 1      6.906529e+10    6.424678e+08                0.000000
# 2      2.312523e+09    9.411432e+07                1.040583
# 3      8.699448e+10    1.831463e+09                0.000000
# 4      2.165257e+11    4.269521e+09                0.000000
# ..              ...             ...                     ...
# 355    2.922204e+11    8.053318e+09                0.000000
# 356    2.575748e+11    7.925380e+09                0.393856
# 357    2.527737e+11    8.006408e+09                0.000000
# 358    3.836843e+11    5.328948e+09                0.000000
# 359    1.371302e+11    3.265004e+09                0.000000
#
# [360 rows x 7 columns]

# %%
from scipy.stats import zscore
from scipy.special import expit

# %%
gdf = gpd.read_postgis("""select * from sa2_metrics""", conn, crs=7844)

# Calculate z-scores
gdf['businesses_per_1000_z'] = zscore(gdf['businesses_per_1000'])
gdf['stops_per_sqkm_z'] = zscore(gdf['stops_per_sqkm'])
gdf['polls_per_sqkm_z'] = zscore(gdf['polls_per_sqkm'])
gdf['schools_per_1000_young_z'] = zscore(gdf['schools_per_1000_young'])

# Calculate the final bustling score using the sigmoid function
gdf['final_bustling_score'] = expit(gdf['businesses_per_1000_z'] + gdf['stops_per_sqkm_z'] + gdf['polls_per_sqkm_z'] + gdf['schools_per_1000_young_z'])

# %%
# Plot the final bustling score on a map
fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(column='final_bustling_score', ax=ax, legend=True, cmap='viridis')
ax.set_title('Final Bustling Score')
plt.show()

# %%
from scipy.stats import pearsonr

# %%
gdf_income = gpd.read_postgis("""SELECT sa2_metrics.sa2_code,sa2_metrics.geom,income.median_income FROM income 
                           Right JOIN sa2_metrics on sa2_metrics.sa2_code = income.sa2_code;""",conn,crs=GDA2020)

# %%
gdf_income['median_income'] = zscore(gdf_income['median_income'].astype(float))
gdf_income.head()
# Out:
#     sa2_code                                               geom  median_income
# 0  102011028  MULTIPOLYGON (((151.41373 -33.46558, 151.41362...      -0.435398
# 1  102011029  MULTIPOLYGON (((151.37484 -33.50052, 151.37507...      -0.744850
# 2  102011030  MULTIPOLYGON (((151.20449 -33.53280, 151.20448...      -1.016927
# 3  102011031  MULTIPOLYGON (((151.37194 -33.43698, 151.37288...      -0.747020
# 4  102011032  MULTIPOLYGON (((151.32349 -33.42779, 151.32342...      -0.503738

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot the final bustling score on a map
gdf.plot(column='final_bustling_score', ax=ax1, legend=True, cmap='viridis')
ax1.set_title('Final Bustling Score')

# Plot the median income on a map
gdf_income.plot(column='median_income', ax=ax2, legend=True, cmap='plasma')
ax2.set_title('Median Income')


plt.tight_layout()
plt.show()

# %%
# Calculate the Pearson correlation coefficient
corr, p_value = pearsonr(gdf['final_bustling_score'], gdf_income['median_income'])
print(f"Pearson correlation coefficient: {corr:.4f}")
print(f"p-value: {p_value:.4f}")
# Out:
# Pearson correlation coefficient: 0.0747
# p-value: 0.1575

# %% [markdown]
# The correlation value of 0.0683 is considered low, and the high p-value suggests that the correlation is not statistically significant. This means that there is no strong linear relationship between the "final bustling score" and the median income of the regions based on the available data.

# %% [markdown]
# # Task 3: Analysis of additional datasest

# %% [markdown]
# ## Parcel count among SA2 region

# %%
f_parcel = pd.read_csv("newDataset/parcel_counts_2022.csv")
f_parcel
# Out:
#        sua_code_2016                            sua_name_2016  sa2_code_2016  \
# 0               1000  Not in any Significant Urban Area (NSW)      101021007
# 1               1000  Not in any Significant Urban Area (NSW)      101021007
# 2               1000  Not in any Significant Urban Area (NSW)      101021007
# 3               1000  Not in any Significant Urban Area (NSW)      101021007
# 4               1000  Not in any Significant Urban Area (NSW)      101021007
# ...              ...                                      ...            ...
# 46793           8001                    Canberra - Queanbeyan      801101139
# 46794           8001                    Canberra - Queanbeyan      801101139
# 46795           8001                    Canberra - Queanbeyan      801101139
# 46796           8001                    Canberra - Queanbeyan      801101139
# 46797           8001                    Canberra - Queanbeyan      801101139
#
#       sa2_name_2016  area_range                 zone  count
# 0         Braidwood       < 200  Business/Commercial      4
# 1         Braidwood       < 200     Mixed Use/Centre     11
# 2         Braidwood       < 200   Primary Production     28
# 3         Braidwood       < 200          Residential      9
# 4         Braidwood       < 200    Special Use N.E.S      2
# ...             ...         ...                  ...    ...
# 46793        Wright     > 10000          Residential      5
# 46794        Wright   200 - 400          Residential    115
# 46795        Wright   400 - 600          Residential    482
# 46796        Wright   600 - 800          Residential    127
# 46797        Wright  800 - 1000          Residential      7
#
# [46798 rows x 7 columns]

# %%
f_parcel = f_parcel[['sa2_code_2016', 'count']]
f_parcel
# Out:
#        sa2_code_2016  count
# 0          101021007      4
# 1          101021007     11
# 2          101021007     28
# 3          101021007      9
# 4          101021007      2
# ...              ...    ...
# 46793      801101139      5
# 46794      801101139    115
# 46795      801101139    482
# 46796      801101139    127
# 46797      801101139      7
#
# [46798 rows x 2 columns]

# %%
f_parcel = f_parcel.rename(columns = {'sa2_code_2016' : 'sa2_code', 'count' : 'parcel_count'})
f_parcel['sa2_code']=f_parcel['sa2_code'].apply(int)
f_parcel
# Out:
#         sa2_code  parcel_count
# 0      101021007             4
# 1      101021007            11
# 2      101021007            28
# 3      101021007             9
# 4      101021007             2
# ...          ...           ...
# 46793  801101139             5
# 46794  801101139           115
# 46795  801101139           482
# 46796  801101139           127
# 46797  801101139             7
#
# [46798 rows x 2 columns]

# %%
conn.execute(text("""
 drop table if exists parcel CASCADE;
 create table parcel(
     id INT PRIMARY KEY,
     sa2_code Numeric,
     parcel_count integer
);"""))

# %%
f_parcel.to_sql("parcel", conn, if_exists = 'replace', index = False)
query(conn, "select * from parcel")
# Out:
#         sa2_code  parcel_count
# 0      101021007             4
# 1      101021007            11
# 2      101021007            28
# 3      101021007             9
# 4      101021007             2
# ...          ...           ...
# 46793  801101139             5
# 46794  801101139           115
# 46795  801101139           482
# 46796  801101139           127
# 46797  801101139             7
#
# [46798 rows x 2 columns]

# %%
sql = """
select sa2_code, sum(parcel_count) as parcel_total from parcel
group by sa2_code
"""
parcel_total = query(conn, sql)

# %%
parcel_total
# Out:
#        sa2_code  parcel_total
# 0     504021051        2312.0
# 1     212021299        2908.0
# 2     701041041        1757.0
# 3     125011587        1480.0
# 4     115011556        2584.0
# ...         ...           ...
# 1623  119041377        4271.0
# 1624  210011231        3497.0
# 1625  202011024        4223.0
# 1626  124011453        6256.0
# 1627  211051281        7084.0
#
# [1628 rows x 2 columns]

# %% [markdown]
# ## Ambulance Station dataset

# %%
import requests
import json
from io import StringIO
from pandas import json_normalize

# %%
# json_buffer = StringIO("newDataset/Ambulance_Station_EPSG4326.json")
f_ambulance = open("newDataset/Ambulance_Station_EPSG4326.json")
df = json.load(f_ambulance)
df
# Out:
# {'Hospital': {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.18341666109134, -33.82714790907171, 0]},
#     'properties': {'topoid': 500168021,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 3157,
#      'generalname': 'GREENWICH HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 6,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151445.417000',
#      'msoid': 9460,
#      'centroidid': None,
#      'shapeuuid': '8ac7703b-d946-356a-9b52-e1329045d005',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19980702085350'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.07950367049494, -34.036578514612934, 0]},
#     'properties': {'topoid': 500213559,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 6221,
#      'generalname': 'PRESIDENT PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151445.450000',
#      'msoid': 9467,
#      'centroidid': None,
#      'shapeuuid': 'e0bf4df6-6992-3ebd-9976-a1009dfadf30',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19980803111024'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.11421755098846, -34.03706152997074, 0]},
#     'properties': {'topoid': 500214035,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 7522,
#      'generalname': 'SUTHERLAND HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151448.441000',
#      'msoid': 9597,
#      'centroidid': None,
#      'shapeuuid': '0a06aa0a-a1b6-3885-958a-4560fe1fc3bd',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20000426163430'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.91693003697367, -33.775523363467826, 0]},
#     'properties': {'topoid': 500253972,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 57899,
#      'generalname': 'BLACKTOWN HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 6,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151449.899000',
#      'msoid': 15669,
#      'centroidid': None,
#      'shapeuuid': 'b83b6b4f-7946-3c57-8c4a-8caf40fedf99',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19980827175953'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.99793199211868, -33.80093480327429, 0]},
#     'properties': {'topoid': 500254138,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 1996,
#      'generalname': 'CUMBERLAND HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151445.520000',
#      'msoid': 9470,
#      'centroidid': None,
#      'shapeuuid': '1344a594-0ccd-35dc-b1a0-b29a9fe06344',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19980827175953'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.82945518391233, -33.76573093282124, 0]},
#     'properties': {'topoid': 500255050,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 5210,
#      'generalname': 'MOUNT DRUITT HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151445.558000',
#      'msoid': 9471,
#      'centroidid': None,
#      'shapeuuid': '411eabff-ee9f-37e2-985b-01fc371d8294',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19980827175953'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.9824131104952, -33.80285746911844, 0]},
#     'properties': {'topoid': 500261260,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 57902,
#      'generalname': 'WESTMEAD PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151445.652000',
#      'msoid': 9473,
#      'centroidid': None,
#      'shapeuuid': '678ee78c-71e3-34d4-9a4b-2a1eb7343926',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19980827175953'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.29413551735064, -33.80574006980713, 0]},
#     'properties': {'topoid': 500278444,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 57908,
#      'generalname': 'MANLY HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151449.925000',
#      'msoid': 15670,
#      'centroidid': None,
#      'shapeuuid': 'f52681df-082c-3a29-9d2b-528625b3a93f',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '19980828173558'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.2394733386375, -33.91777777005075, 0]},
#     'properties': {'topoid': 500324529,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 57917,
#      'generalname': 'PRINCE OF WALES HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151449.948000',
#      'msoid': 15671,
#      'centroidid': None,
#      'shapeuuid': 'db945c74-9885-3934-8bc4-a3cd0aca6fbb',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19980918124308'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [149.09590059949215, -35.31963103883377, 0]},
#     'properties': {'topoid': 500686808,
#      'objectmoddate': '20150716103433',
#      'featuremoddate': '20150716103433',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20150710000000',
#      'attributereliabilitydate': '20150710000000',
#      'capturesourcecode': 12,
#      'capturemethodcode': 2,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 75552,
#      'generalname': 'CALVARY JOHN JAMES HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20150716104138',
#      'enddate': '30000101000000',
#      'lastupdate': '20150716104343.293000',
#      'msoid': 15815,
#      'centroidid': None,
#      'shapeuuid': '95d7b211-99fb-32c8-9d6d-41446a6c4ce0',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20021112131300'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [149.10122488992664, -35.34676910167868, 0]},
#     'properties': {'topoid': 500693917,
#      'objectmoddate': '20150119112135',
#      'featuremoddate': '20150119112135',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 12,
#      'capturemethodcode': 2,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 101647,
#      'generalname': 'THE CANBERRA HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20150119112324',
#      'enddate': '30000101000000',
#      'lastupdate': '20150119112358.850000',
#      'msoid': 15813,
#      'centroidid': None,
#      'shapeuuid': 'b499398c-5175-31fe-b1b0-08d031c71795',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20021021121521'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [147.15424461670122, -33.082233013648626, 0]},
#     'properties': {'topoid': 500939741,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 56372,
#      'generalname': 'CONDOBOLIN HEALTH SERVICE',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 6,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151450.412000',
#      'msoid': 15690,
#      'centroidid': None,
#      'shapeuuid': '3379826a-087a-3fbd-b5c0-8c73b07be415',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '19981022143838'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [149.5893393702642, -33.43503295556405, 0]},
#     'properties': {'topoid': 501081922,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 89461,
#      'generalname': 'BATHURST PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151446.137000',
#      'msoid': 9494,
#      'centroidid': None,
#      'shapeuuid': '5d2c4652-1bd0-3bfe-ab29-995f341056a0',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '19981022180345'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [148.85960876584687, -33.08754297036914, 0]},
#     'properties': {'topoid': 501110801,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 56710,
#      'generalname': 'MOLONG HEALTH SERVICE',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151446.301000',
#      'msoid': 9500,
#      'centroidid': None,
#      'shapeuuid': '0823ff8f-93e9-3e3a-b6a6-3009b5e12494',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981022183104'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [149.1214104188398, -33.28160669682412, 0]},
#     'properties': {'topoid': 501120508,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 56716,
#      'generalname': 'DUDLEY PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151446.326000',
#      'msoid': 9502,
#      'centroidid': None,
#      'shapeuuid': '2f2c7f3b-4403-3847-b52f-be36140000d7',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981022184231'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [149.58833886443, -32.60328496543816, 0]},
#     'properties': {'topoid': 501553873,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 56801,
#      'generalname': 'MUDGEE HEALTH SERVICE',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151451.119000',
#      'msoid': 15716,
#      'centroidid': None,
#      'shapeuuid': 'b82a89c8-f9fb-3bdd-ac4d-a1607b7ae5d7',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981029130410'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [146.8833739436041, -36.07522721546635, 0]},
#     'properties': {'topoid': 501564910,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 75523,
#      'generalname': 'ALBURY WODONGA PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151446.613000',
#      'msoid': 9514,
#      'centroidid': None,
#      'shapeuuid': 'cba92117-110b-3266-b7e9-8e5a7cc24445',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981029160436'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.09285628008206, -33.692023093934935, 0]},
#     'properties': {'topoid': 501572272,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 57911,
#      'generalname': 'MOUNT WILGA PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151446.640000',
#      'msoid': 9515,
#      'centroidid': None,
#      'shapeuuid': 'b568846e-f4c8-3003-811b-248aa8ed9cfe',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981103162042'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.11183200288625, -33.702639798721926, 0]},
#     'properties': {'topoid': 501572549,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 57912,
#      'generalname': 'HORNSBY KU-RING-GAI HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151446.668000',
#      'msoid': 9516,
#      'centroidid': None,
#      'shapeuuid': '2aa8dec0-9da8-3978-88a5-bbf9466d6ebd',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981103162042'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.64794442645842, -33.0248018623209, 0]},
#     'properties': {'topoid': 501629755,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 593,
#      'generalname': 'BELMONT HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151453.119000',
#      'msoid': 15784,
#      'centroidid': None,
#      'shapeuuid': '7885f5af-accb-357f-9cb2-f0338225e44c',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19990831100114'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.5454308745307, -32.72579135602625, 0]},
#     'properties': {'topoid': 501668161,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 97590,
#      'generalname': 'MAITLAND HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151451.351000',
#      'msoid': 15724,
#      'centroidid': None,
#      'shapeuuid': '777a10aa-2e3d-3fe7-b508-7e1188bb72bb',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '19981111174126'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.75576581078627, -32.940647374283856, 0]},
#     'properties': {'topoid': 501671117,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 57928,
#      'generalname': 'LINGARD PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151446.821000',
#      'msoid': 9523,
#      'centroidid': None,
#      'shapeuuid': '6c07dfdd-3bf3-323e-92a7-354170d057d0',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981111174323'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.69161804790025, -32.98144482152564, 0]},
#     'properties': {'topoid': 501677845,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 13812,
#      'generalname': 'LAKE MACQUARIE PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151446.855000',
#      'msoid': 9525,
#      'centroidid': None,
#      'shapeuuid': '043f0485-cc5c-31ef-91d6-6079e13be7ef',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981111175205'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.48035200515776, -33.261167451276, 0]},
#     'properties': {'topoid': 501732158,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 14358,
#      'generalname': 'WYONG HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 6,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151453.095000',
#      'msoid': 15782,
#      'centroidid': None,
#      'shapeuuid': 'ca4adfd5-6293-3886-a584-7f17dd9b9576',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '19990705113034'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.5710569924095, -33.690544566234564, 0]},
#     'properties': {'topoid': 501764785,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 15209,
#      'generalname': 'SPRINGWOOD HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151446.907000',
#      'msoid': 9527,
#      'centroidid': None,
#      'shapeuuid': 'de686173-42e2-3748-8a72-4c82f3f2bb60',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981112121141'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.71201522522372, -33.75992366347957, 0]},
#     'properties': {'topoid': 501813710,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 57883,
#      'generalname': 'NEPEAN HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151446.943000',
#      'msoid': 9530,
#      'centroidid': None,
#      'shapeuuid': '60a36bd0-d371-30ab-8717-4d48e37e1330',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981112153533'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.87689127405588, -32.05149809114234, 0]},
#     'properties': {'topoid': 502069823,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 97585,
#      'generalname': 'SCOTT MEMORIAL SCONE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151451.760000',
#      'msoid': 15740,
#      'centroidid': None,
#      'shapeuuid': 'eb41aafb-1357-34c7-8f75-ed3e8dcefa87',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981118111633'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.91761165795003, -34.31032121054521, 0]},
#     'properties': {'topoid': 502106560,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 17265,
#      'generalname': 'LAWRENCE HARGRAVE PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151447.007000',
#      'msoid': 9534,
#      'centroidid': None,
#      'shapeuuid': 'ebac52c8-b559-3d1a-b4c3-dccf7f5bb0a0',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981124104347'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.88338944247946, -34.42502858980466, 0]},
#     'properties': {'topoid': 502130356,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 57876,
#      'generalname': 'WOLLONGONG HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151451.865000',
#      'msoid': 15743,
#      'centroidid': None,
#      'shapeuuid': 'c40ffeb5-010f-3af3-ba94-71c3d5428778',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981124110224'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.92483213474407, -31.074180554460465, 0]},
#     'properties': {'topoid': 502329548,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 97573,
#      'generalname': 'TAMWORTH HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151451.992000',
#      'msoid': 15748,
#      'centroidid': None,
#      'shapeuuid': '4180b4f2-7ad2-30a7-b1c1-3a115fc05b38',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '19981124193047'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.92211976067688, -31.077636984105467, 0]},
#     'properties': {'topoid': 502329581,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 11843,
#      'generalname': 'TAMARA PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151447.123000',
#      'msoid': 9539,
#      'centroidid': None,
#      'shapeuuid': 'e2dd7218-c32c-30c7-aee4-33e83657c6ce',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981124193047'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.1821778474232, -35.71388183964307, 0]},
#     'properties': {'topoid': 502722238,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 16469,
#      'generalname': 'BATEMANS BAY DISTRICT HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151447.289000',
#      'msoid': 9547,
#      'centroidid': None,
#      'shapeuuid': '2d42ae28-8455-393f-be8a-6703bd4283e4',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981130153322'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.8411206918189, -34.55855380038749, 0]},
#     'properties': {'topoid': 502743341,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 57293,
#      'generalname': 'SHELLHARBOUR HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151447.329000',
#      'msoid': 9548,
#      'centroidid': None,
#      'shapeuuid': 'f367f8b6-0f0a-3f52-894b-856b4d973a5a',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981203142417'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.84789068415924, -34.5589192350343, 0]},
#     'properties': {'topoid': 502743419,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 57292,
#      'generalname': 'SHELLHARBOUR PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151447.357000',
#      'msoid': 9549,
#      'centroidid': None,
#      'shapeuuid': 'c6582d38-c71a-3527-aa5b-33113007ed7f',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981203142417'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.71292133159636, -34.77604449347273, 0]},
#     'properties': {'topoid': 502746198,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 49800,
#      'generalname': 'DAVID BERRY HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 2,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151447.382000',
#      'msoid': 9550,
#      'centroidid': None,
#      'shapeuuid': 'c347ac13-a61d-3d0f-b68d-9ddd85868fc0',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '19981203142659'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [148.62088801613245, -32.236825773544915, 0]},
#     'properties': {'topoid': 502755173,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 56503,
#      'generalname': 'DUBBO PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151447.443000',
#      'msoid': 9552,
#      'centroidid': None,
#      'shapeuuid': '55132e18-7bcc-36f0-b54d-f575e123abec',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981203143454'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [152.51386677494466, -32.18848297648538, 0]},
#     'properties': {'topoid': 503109176,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 89383,
#      'generalname': 'FORSTER PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151447.499000',
#      'msoid': 9554,
#      'centroidid': None,
#      'shapeuuid': '830cbca2-5571-37b1-be27-17a656861ee2',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981209102140'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.65469069968202, -30.512062513666013, 0]},
#     'properties': {'topoid': 503323719,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 12168,
#      'generalname': 'ARMIDALE PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151452.562000',
#      'msoid': 15764,
#      'centroidid': None,
#      'shapeuuid': '49b1cddf-83c4-3e29-8aee-07697ef28585',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981209181002'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [153.56412106884108, -28.862623110538397, 0]},
#     'properties': {'topoid': 503565536,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 16234,
#      'generalname': 'BALLINA DISTRICT HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151452.792000',
#      'msoid': 15772,
#      'centroidid': None,
#      'shapeuuid': 'f696afdb-3f16-3b88-9bd3-a9ee39a0efdc',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981215101558'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [153.20108971187005, -29.454260002624824, 0]},
#     'properties': {'topoid': 503767189,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 55973,
#      'generalname': 'MACLEAN DISTRICT HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 6,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151452.962000',
#      'msoid': 15777,
#      'centroidid': None,
#      'shapeuuid': '56cb1e00-9dcb-34bd-af9c-3ad247fc6143',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981215154839'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.11455587898234, -33.71762468649579, 0]},
#     'properties': {'topoid': 503935668,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 10913,
#      'generalname': 'NERINGAH HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151447.754000',
#      'msoid': 9565,
#      'centroidid': None,
#      'shapeuuid': '68db3912-4d0d-342c-9653-d4515d9f7034',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19990107145735'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.69340562704363, -32.92264745202252, 0]},
#     'properties': {'topoid': 504036591,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 13787,
#      'generalname': 'JOHN HUNTER HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151453.514000',
#      'msoid': 15801,
#      'centroidid': None,
#      'shapeuuid': 'e2bb2476-f02b-383c-b198-19b583c4eb19',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20001204124128'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.59324451850335, -33.015570190702114, 0]},
#     'properties': {'topoid': 504068128,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 15967,
#      'generalname': 'TORONTO PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151449.527000',
#      'msoid': 9650,
#      'centroidid': None,
#      'shapeuuid': 'd6cb8c44-8ea2-362a-81a4-845b6e56e80d',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20010503144003'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.9952893389956, -33.80183535170975, 0]},
#     'properties': {'topoid': 504301208,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 1996,
#      'generalname': 'CUMBERLAND HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151448.248000',
#      'msoid': 9589,
#      'centroidid': None,
#      'shapeuuid': 'c8d5bba4-2ccd-33a6-bf33-0c0b52091663',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20000322084133'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.28817110900434, -33.75802413303768, 0]},
#     'properties': {'topoid': 504331140,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 20972,
#      'generalname': 'DELMAR PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151448.335000',
#      'msoid': 9593,
#      'centroidid': None,
#      'shapeuuid': '6def5006-1cf8-3a97-8456-cf556cea878d',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20000403175455'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.29140295544408, -33.77513524164746, 0]},
#     'properties': {'topoid': 504331148,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 20979,
#      'generalname': 'SOUTH PACIFIC PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 6,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151448.376000',
#      'msoid': 9594,
#      'centroidid': None,
#      'shapeuuid': '2d289790-e5e7-3bf0-80f8-8d120860bcf2',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20000403175455'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.2479114287986, -33.83480906438014, 0]},
#     'properties': {'topoid': 504331458,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 21084,
#      'generalname': 'MOSMAN PRIVATE HOSPITAL',
#      'alternativelabel': None,
#      'buildingcomplextype': 0,
#      'relevance': 7,
#      'startdate': '20141223151337',
#      'enddate': '30000101000000',
#      'lastupdate': '20141223151448.399000',
#      'msoid': 9596,
#      'centroidid': None,
#      'shapeuuid': '5c974047-5dc8-3f8c-854a-b20696e8ae3e',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20000404125909'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [151.11430557780147, -34.03506823613065, 0]},
#     'properties': {'topoid': 504371331,
#      'objectmoddate': '20141223151106',
#      'featuremoddate': '20141223151106',
#      'classsubtype': 3,
#      'featurereliabilitydate': '20140723000000',
#      'attributereliabilitydate': '20140723000000',
#      'capturesourcecode': 42,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
# ...
#      'objectmoddate': '20230602095044',
#      'featuremoddate': '20230602095044',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20130901000000',
#      'attributereliabilitydate': '20130901000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 16031,
#      'generalname': 'KATOOMBA AMBULANCE STATION',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230602095322',
#      'enddate': '30000101000000',
#      'lastupdate': '20230602095430.907000',
#      'msoid': 8355,
#      'centroidid': None,
#      'shapeuuid': '252229b1-9153-3115-92a9-ddcf70a1c917',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981216151025'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.36746244900573, -33.50525665723376, 0]},
#     'properties': {'topoid': 517913042,
#      'objectmoddate': '20230602095044',
#      'featuremoddate': '20230602095044',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20130901000000',
#      'attributereliabilitydate': '20130901000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 108180,
#      'generalname': 'MOUNT WILSON CFR',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 1,
#      'startdate': '20230602095322',
#      'enddate': '30000101000000',
#      'lastupdate': '20230602095529.179000',
#      'msoid': 140531,
#      'centroidid': None,
#      'shapeuuid': '4932e516-8605-3040-bf6c-1436ad8bf89c',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '20170123120347'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [149.5298859982371, -33.946215995559, 0]},
#     'properties': {'topoid': 517913056,
#      'objectmoddate': '20230602095044',
#      'featuremoddate': '20230602095044',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20131101000000',
#      'attributereliabilitydate': '20131101000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 108160,
#      'generalname': 'BURRAGA CFR',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 1,
#      'startdate': '20230602095322',
#      'enddate': '30000101000000',
#      'lastupdate': '20230602095529.213000',
#      'msoid': 140545,
#      'centroidid': None,
#      'shapeuuid': '797824ee-4465-34c1-b9cb-fe8501bb66c4',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '20170123120347'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [145.573433791517, -35.63729641091641, 0]},
#     'properties': {'topoid': 501163107,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20140201000000',
#      'attributereliabilitydate': '20140201000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 84240,
#      'generalname': 'FINLEY AMBULANCE STATION',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112347.680000',
#      'msoid': 8259,
#      'centroidid': None,
#      'shapeuuid': '6187d7b4-a4e7-3ac9-a744-4edf717752fb',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981023152402'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [146.39151184820807, -35.99599847977075, 0]},
#     'properties': {'topoid': 501172789,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20150201000000',
#      'attributereliabilitydate': '20150201000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 70949,
#      'generalname': 'COROWA AMBULANCE STATION',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112347.720000',
#      'msoid': 8261,
#      'centroidid': None,
#      'shapeuuid': 'a5ddaeb6-2f1e-31b9-89a3-0d64280b1ab2',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981023181939'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [149.2348729976747, -36.917466002522, 0]},
#     'properties': {'topoid': 501348510,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20110101000000',
#      'attributereliabilitydate': '20110101000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 102192,
#      'generalname': 'BOMBALA AMBULANCE STATION',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112347.752000',
#      'msoid': 8265,
#      'centroidid': None,
#      'shapeuuid': '1c50410a-66cb-34f4-bcc5-fa0ff54230e1',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '19981026185212'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.66995058437217, -35.04173289263123, 0]},
#     'properties': {'topoid': 502716067,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20140101000000',
#      'attributereliabilitydate': '20140101000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 16783,
#      'generalname': 'HUSKISSON AMBULANCE STATION',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112347.789000',
#      'msoid': 8328,
#      'centroidid': None,
#      'shapeuuid': '60388ee6-8d26-3185-845f-d1bb6bbff173',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981130152721'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.47371026972172, -35.361797841564254, 0]},
#     'properties': {'topoid': 502717243,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20131201000000',
#      'attributereliabilitydate': '20131201000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 16686,
#      'generalname': 'ULLADULLA AMBULANCE STATION',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112347.829000',
#      'msoid': 8329,
#      'centroidid': None,
#      'shapeuuid': '784fe3cb-0346-3d93-acec-a3a704c923bc',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '19981130152949'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [149.13155600423502, -36.24164099896358, 0]},
#     'properties': {'topoid': 505184718,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20110301000000',
#      'attributereliabilitydate': '20110301000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 32761,
#      'generalname': 'COOMA AMBULANCE STATION',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112347.865000',
#      'msoid': 8414,
#      'centroidid': None,
#      'shapeuuid': 'def2dadf-5229-35d4-b408-82e8f00dcd74',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20010530163020'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [148.62289911228828, -36.41637398340505, 0]},
#     'properties': {'topoid': 505218077,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20110201000000',
#      'attributereliabilitydate': '20110201000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 32439,
#      'generalname': 'JINDABYNE AMBULANCE STATION',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112347.905000',
#      'msoid': 8415,
#      'centroidid': None,
#      'shapeuuid': '5f23488f-c348-3756-a7b9-953097edb6ce',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20010613163033'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.58542417275322, -35.16663508687365, 0]},
#     'properties': {'topoid': 513007813,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20140101000000',
#      'attributereliabilitydate': '20140101000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 61330,
#      'generalname': 'SUSSEX INLET AMBULANCE STATION',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112536.566000',
#      'msoid': 51700,
#      'centroidid': None,
#      'shapeuuid': '577a9dd6-939b-37d5-ad48-15944b4f84b5',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '20070419121150'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [145.81260986670628, -35.662409834035586, 0]},
#     'properties': {'topoid': 516738886,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20140201000000',
#      'attributereliabilitydate': '20140201000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 89116,
#      'generalname': 'BERRIGAN AMBULANCE STATION',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112626.211000',
#      'msoid': 100822,
#      'centroidid': None,
#      'shapeuuid': '13984ba7-6401-33d4-acb1-24d52e967ddb',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20101216162834'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [149.4392179963618, -35.59095799577632, 0]},
#     'properties': {'topoid': 517913036,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20081001000000',
#      'attributereliabilitydate': '20081001000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 108162,
#      'generalname': 'CAPTAINS FLAT CFR',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 1,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112645.301000',
#      'msoid': 140525,
#      'centroidid': None,
#      'shapeuuid': '093fec8b-c557-3104-b1aa-8f5936351293',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '20170123120347'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [145.70756281684402, -33.97943815448045, 0]},
#     'properties': {'topoid': 517913061,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20120201000000',
#      'attributereliabilitydate': '20120201000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 108170,
#      'generalname': 'GOOLGOWI CFR',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112645.377000',
#      'msoid': 140550,
#      'centroidid': None,
#      'shapeuuid': '3b64a160-99e1-3fd2-b7db-63972cb3d15b',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20170123120347'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [145.5688350011673, -35.81230700075857, 0]},
#     'properties': {'topoid': 517913068,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20140201000000',
#      'attributereliabilitydate': '20140201000000',
#      'capturesourcecode': 35,
#      'capturemethodcode': 20,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 108195,
#      'generalname': 'TOCUMWAL CFR',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 6,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112645.450000',
#      'msoid': 140557,
#      'centroidid': None,
#      'shapeuuid': 'c9c15cba-54b8-36df-b6ac-42a7ed472a28',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'U',
#      'createdate': '20170123120347'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [150.61272200063894, -35.08815700302213, 0]},
#     'properties': {'topoid': 518271570,
#      'objectmoddate': '20230605110945',
#      'featuremoddate': '20230605110945',
#      'classsubtype': 2,
#      'featurereliabilitydate': '20140101000000',
#      'attributereliabilitydate': '20140101000000',
#      'capturesourcecode': 4,
#      'capturemethodcode': 2,
#      'planimetricaccuracy': 10,
#      'verticalaccuracy': None,
#      'operationalstatus': 1,
#      'generalnameoid': 109838,
#      'generalname': 'BAY AND BASIN',
#      'alternativelabel': None,
#      'buildingcomplextype': 1,
#      'relevance': 1,
#      'startdate': '20230605112035',
#      'enddate': '30000101000000',
#      'lastupdate': '20230605112654.239000',
#      'msoid': 201578,
#      'centroidid': None,
#      'shapeuuid': '41d45d2b-1e46-3205-b5ab-cb92889fe7fc',
#      'changetype': 'M',
#      'processstate': None,
#      'urbanity': 'S',
#      'createdate': '20200908124820'}}]}}

# %%
f_ambulance = pd.read_json("newDataset/Ambulance_Station_EPSG4326.json")
f_ambulance
# Out:
#                                                    Hospital  \
# type                                      FeatureCollection
# features  [{'type': 'Feature', 'geometry': {'type': 'Poi...
#
#                                       NSW Ambulance Station
# type                                      FeatureCollection
# features  [{'type': 'Feature', 'geometry': {'type': 'Poi...

# %%
f_ambulance = json_normalize(df['NSW Ambulance Station']['features'])
f_ambulance
# Out:
#         type geometry.type                          geometry.coordinates  \
# 0    Feature         Point    [149.1345155156166, -35.25335461689909, 0]
# 1    Feature         Point   [149.13231164908572, -35.18239599494639, 0]
# 2    Feature         Point    [149.1156290826567, -35.43405890298268, 0]
# 3    Feature         Point   [149.08702495163428, -35.34927953644504, 0]
# 4    Feature         Point   [149.05487003541532, -35.37252544862082, 0]
# ..       ...           ...                                           ...
# 311  Feature         Point  [145.81260986670628, -35.662409834035586, 0]
# 312  Feature         Point    [149.4392179963618, -35.59095799577632, 0]
# 313  Feature         Point   [145.70756281684402, -33.97943815448045, 0]
# 314  Feature         Point    [145.5688350011673, -35.81230700075857, 0]
# 315  Feature         Point   [150.61272200063894, -35.08815700302213, 0]
#
#      properties.topoid properties.objectmoddate properties.featuremoddate  \
# 0            500694818           20150716103433            20150716103433
# 1            505847645           20141210093650            20141210093650
# 2            505860758           20141210093650            20141210093650
# 3            505926282           20141210093650            20141210093650
# 4            505965043           20141210093650            20141210093650
# ..                 ...                      ...                       ...
# 311          516738886           20230605110945            20230605110945
# 312          517913036           20230605110945            20230605110945
# 313          517913061           20230605110945            20230605110945
# 314          517913068           20230605110945            20230605110945
# 315          518271570           20230605110945            20230605110945
#
#      properties.classsubtype properties.featurereliabilitydate  \
# 0                          2                    20150710000000
# 1                          2                    20130201000000
# 2                          2                    20130201000000
# 3                          2                    20130201000000
# 4                          2                    20130201000000
# ..                       ...                               ...
# 311                        2                    20140201000000
# 312                        2                    20081001000000
# 313                        2                    20120201000000
# 314                        2                    20140201000000
# 315                        2                    20140101000000
#
#     properties.attributereliabilitydate  properties.capturesourcecode  ...  \
# 0                        20150710000000                            12  ...
# 1                        20130201000000                             4  ...
# 2                        20130201000000                             4  ...
# 3                        20130201000000                            12  ...
# 4                        20130201000000                             4  ...
# ..                                  ...                           ...  ...
# 311                      20140201000000                            35  ...
# 312                      20081001000000                            35  ...
# 313                      20120201000000                            35  ...
# 314                      20140201000000                            35  ...
# 315                      20140101000000                             4  ...
#
#      properties.startdate  properties.enddate  properties.lastupdate  \
# 0          20150716104138      30000101000000  20150716104341.291000
# 1          20141210093736      30000101000000  20141210093759.179000
# 2          20141210093736      30000101000000  20141210093759.260000
# 3          20141210093736      30000101000000  20141210093759.354000
# 4          20141210093736      30000101000000  20141210093759.610000
# ..                    ...                 ...                    ...
# 311        20230605112035      30000101000000  20230605112626.211000
# 312        20230605112035      30000101000000  20230605112645.301000
# 313        20230605112035      30000101000000  20230605112645.377000
# 314        20230605112035      30000101000000  20230605112645.450000
# 315        20230605112035      30000101000000  20230605112654.239000
#
#      properties.msoid  properties.centroidid  \
# 0                8238                   None
# 1                8426                   None
# 2                8428                   None
# 3                8430                   None
# 4               15662                   None
# ..                ...                    ...
# 311            100822                   None
# 312            140525                   None
# 313            140550                   None
# 314            140557                   None
# 315            201578                   None
#
#                      properties.shapeuuid properties.changetype  \
# 0    070171c2-df7f-3c24-b248-955fd51e7153                     M
# 1    13b316d0-ea8c-3669-91bd-fba58523e89e                     M
# 2    6b266cdd-5928-346d-bbf0-76dcda224eb4                     M
# 3    d8351b9a-eae0-3d00-8f5e-8caed6047f21                     M
# 4    3f4a3068-6098-3d72-877f-00fd47bdc555                     M
# ..                                    ...                   ...
# 311  13984ba7-6401-33d4-acb1-24d52e967ddb                     M
# 312  093fec8b-c557-3104-b1aa-8f5936351293                     M
# 313  3b64a160-99e1-3fd2-b7db-63972cb3d15b                     M
# 314  c9c15cba-54b8-36df-b6ac-42a7ed472a28                     M
# 315  41d45d2b-1e46-3205-b5ab-cb92889fe7fc                     M
#
#      properties.processstate  properties.urbanity properties.createdate
# 0                       None                    U        19981007172657
# 1                       None                    S        20020905125238
# 2                       None                    U        20020919112746
# 3                       None                    U        20021021121521
# 4                       None                    S        20021128141813
# ..                       ...                  ...                   ...
# 311                     None                    U        20101216162834
# 312                     None                    S        20170123120347
# 313                     None                    U        20170123120347
# 314                     None                    U        20170123120347
# 315                     None                    S        20200908124820
#
# [316 rows x 29 columns]

# %%
f_ambulance = f_ambulance[['properties.topoid', 'geometry.coordinates']]

# %%
f_ambulance = f_ambulance.rename(columns = {'properties.topoid': 'properties', 
                                            'geometry.coordinates' : 'geom'})
f_ambulance
# Out:
#      properties                                          geom
# 0     500694818    [149.1345155156166, -35.25335461689909, 0]
# 1     505847645   [149.13231164908572, -35.18239599494639, 0]
# 2     505860758    [149.1156290826567, -35.43405890298268, 0]
# 3     505926282   [149.08702495163428, -35.34927953644504, 0]
# 4     505965043   [149.05487003541532, -35.37252544862082, 0]
# ..          ...                                           ...
# 311   516738886  [145.81260986670628, -35.662409834035586, 0]
# 312   517913036    [149.4392179963618, -35.59095799577632, 0]
# 313   517913061   [145.70756281684402, -33.97943815448045, 0]
# 314   517913068    [145.5688350011673, -35.81230700075857, 0]
# 315   518271570   [150.61272200063894, -35.08815700302213, 0]
#
# [316 rows x 2 columns]

# %%
f_ambulance['lat'] = f_ambulance['geom'].apply(lambda coord: coord[1])
f_ambulance['lon'] = f_ambulance['geom'].apply(lambda coord: coord[0])
f_ambulance
# Out:
#      properties                                          geom        lat  \
# 0     500694818    [149.1345155156166, -35.25335461689909, 0] -35.253355
# 1     505847645   [149.13231164908572, -35.18239599494639, 0] -35.182396
# 2     505860758    [149.1156290826567, -35.43405890298268, 0] -35.434059
# 3     505926282   [149.08702495163428, -35.34927953644504, 0] -35.349280
# 4     505965043   [149.05487003541532, -35.37252544862082, 0] -35.372525
# ..          ...                                           ...        ...
# 311   516738886  [145.81260986670628, -35.662409834035586, 0] -35.662410
# 312   517913036    [149.4392179963618, -35.59095799577632, 0] -35.590958
# 313   517913061   [145.70756281684402, -33.97943815448045, 0] -33.979438
# 314   517913068    [145.5688350011673, -35.81230700075857, 0] -35.812307
# 315   518271570   [150.61272200063894, -35.08815700302213, 0] -35.088157
#
#             lon
# 0    149.134516
# 1    149.132312
# 2    149.115629
# 3    149.087025
# 4    149.054870
# ..          ...
# 311  145.812610
# 312  149.439218
# 313  145.707563
# 314  145.568835
# 315  150.612722
#
# [316 rows x 4 columns]

# %%
f_ambulance = f_ambulance.drop(columns = "geom")
f_ambulance
# Out:
#      properties        lat         lon
# 0     500694818 -35.253355  149.134516
# 1     505847645 -35.182396  149.132312
# 2     505860758 -35.434059  149.115629
# 3     505926282 -35.349280  149.087025
# 4     505965043 -35.372525  149.054870
# ..          ...        ...         ...
# 311   516738886 -35.662410  145.812610
# 312   517913036 -35.590958  149.439218
# 313   517913061 -33.979438  145.707563
# 314   517913068 -35.812307  145.568835
# 315   518271570 -35.088157  150.612722
#
# [316 rows x 3 columns]

# %%
f_ambulance['geom'] = gpd.points_from_xy(f_ambulance.lon, f_ambulance.lat)  # creating the geometry column
f_ambulance = f_ambulance.drop(columns=['lat', 'lon'])  # removing the old latitude/longitude fields
f_ambulance = f_ambulance.drop_duplicates().dropna()
f_ambulance
# Out:
#      properties                         geom
# 0     500694818  POINT (149.13452 -35.25335)
# 1     505847645  POINT (149.13231 -35.18240)
# 2     505860758  POINT (149.11563 -35.43406)
# 3     505926282  POINT (149.08702 -35.34928)
# 4     505965043  POINT (149.05487 -35.37253)
# ..          ...                          ...
# 311   516738886  POINT (145.81261 -35.66241)
# 312   517913036  POINT (149.43922 -35.59096)
# 313   517913061  POINT (145.70756 -33.97944)
# 314   517913068  POINT (145.56884 -35.81231)
# 315   518271570  POINT (150.61272 -35.08816)
#
# [316 rows x 2 columns]

# %%
f_ambulance = gpd.GeoDataFrame(f_ambulance, geometry = 'geom')
f_ambulance = f_ambulance.set_crs('epsg:4326')
f_ambulance.crs.name
# Out:
# 'WGS 84'

# %%
f_ambulance.to_crs(GDA2020, inplace = True)

# %%
f_ambulance['geom'] = f_ambulance['geom'].apply(lambda x: WKTElement(x.wkt, srid=GDA2020))
# Out:
# /var/folders/1c/25dx1kl527z_bk2pgcg8jspc0000gn/T/ipykernel_63889/2861681024.py:1: UserWarning: Geometry column does not contain geometry.
#   f_ambulance['geom'] = f_ambulance['geom'].apply(lambda x: WKTElement(x.wkt, srid=GDA2020))

# %%
conn.execute(text("""
 drop table if exists ambulance CASCADE;
 create table ambulance(
     properties Numeric primary key,
     geom GEOMETRY(POINT,7844)
);"""))

f_ambulance.to_sql('ambulance', conn, if_exists='append', index = False, 
                   dtype={'geom': Geometry('POINT', GDA2020)})
query(conn, "select * from ambulance")
# Out:
#       properties                                               geom
# 0    500694818.0  0101000020A41E0000188C7BF34DA46240A4EF90EC6DA0...
# 1    505847645.0  0101000020A41E00007FB6A3E53BA46240AA9B80C05897...
# 2    505860758.0  0101000020A41E0000440FC33BB3A36240936CFC3D8FB7...
# 3    505926282.0  0101000020A41E000091268DE8C8A26240C4181D31B5AC...
# 4    505965043.0  0101000020A41E000074F4CD7EC1A162408860F5E9AEAF...
# ..           ...                                                ...
# 311  516738886.0  0101000020A41E0000223D68E6003A6240A6DD6ED8C9D4...
# 312  517913036.0  0101000020A41E00000946E6120EAE6240A295F882A4CB...
# 313  517913061.0  0101000020A41E0000BEC6C65AA43662405CF9BC3A5EFD...
# 314  517913068.0  0101000020A41E0000ADDA75E533326240F34801ADF9E7...
# 315  518271570.0  0101000020A41E000016492B6B9BD362405C728ABA488B...
#
# [316 rows x 2 columns]

# %% [markdown]
# ## Steal Dataset

# %%
f_steal = gpd.read_file("newDataset/steal_from_vehicle/StealFromVehicle_JanToDec2022.shp")
f_steal
# Out:
#       OBJECTID  Contour       Density  ORIG_FID   Shape_Leng     Shape_Area  \
# 0            1      8.0   Low Density         1   500.000000   10000.000000
# 1            2      8.0   Low Density         1  2270.710678  228749.999996
# 2            3      8.0   Low Density         1  2104.536894  301249.999995
# 3            4      8.0   Low Density         1  1300.000000   44999.999996
# 4            5      8.0   Low Density         1   800.000000   34999.999999
# ...        ...      ...           ...       ...          ...            ...
# 2341      2342     10.0  High Density         3  2900.000000  392500.000001
# 2342      2343     10.0  High Density         3  2300.000000  242499.999999
# 2343      2344     10.0  High Density         3  2200.000000  242499.999994
# 2344      2345     10.0  High Density         3   400.000000    7500.000002
# 2345      2346     10.0  High Density         3  4700.000000  609999.999991
#
#                                                geometry
# 0     POLYGON ((9553621.246 4115829.876, 9553621.246...
# 1     POLYGON ((9554021.246 4116979.876, 9554021.246...
# 2     POLYGON ((9575271.246 4143279.876, 9575221.246...
# 3     POLYGON ((9294871.246 4188429.876, 9294871.246...
# 4     POLYGON ((9295871.246 4188779.876, 9295871.246...
# ...                                                 ...
# 2341  POLYGON ((9943521.246 5041129.876, 9943521.246...
# 2342  POLYGON ((9942071.246 5041779.876, 9942071.246...
# 2343  POLYGON ((9942921.246 5042029.876, 9942921.246...
# 2344  POLYGON ((9942221.246 5042479.876, 9942121.246...
# 2345  POLYGON ((9944171.246 5043429.876, 9944171.246...
#
# [2346 rows x 7 columns]

# %%
f_steal = f_steal[['OBJECTID', 'geometry']]
f_steal
# Out:
#       OBJECTID                                           geometry
# 0            1  POLYGON ((9553621.246 4115829.876, 9553621.246...
# 1            2  POLYGON ((9554021.246 4116979.876, 9554021.246...
# 2            3  POLYGON ((9575271.246 4143279.876, 9575221.246...
# 3            4  POLYGON ((9294871.246 4188429.876, 9294871.246...
# 4            5  POLYGON ((9295871.246 4188779.876, 9295871.246...
# ...        ...                                                ...
# 2341      2342  POLYGON ((9943521.246 5041129.876, 9943521.246...
# 2342      2343  POLYGON ((9942071.246 5041779.876, 9942071.246...
# 2343      2344  POLYGON ((9942921.246 5042029.876, 9942921.246...
# 2344      2345  POLYGON ((9942221.246 5042479.876, 9942121.246...
# 2345      2346  POLYGON ((9944171.246 5043429.876, 9944171.246...
#
# [2346 rows x 2 columns]

# %%
f_steal['geometry'].crs.name
# Out:
# 'GDA94 / NSW Lambert'

# %%
f_steal.to_crs(GDA2020, inplace = True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
f_steal['geometry'].crs.name
# Out:
# 'GDA2020'

# %% [markdown]
# ## Due to the geometry type of the other datasets is either POINT or Multipolgon (or converted to Multipolygon), to ensure the consistency among all datasets, the geometry type is converted to multipolygon by using the create_wkt_element function.

# %%
stealog = f_steal.copy()  # creating a copy of the original for later
f_steal['geom'] = stealog['geometry'].apply(lambda x: create_wkt_element(geom=x,srid=GDA2020))  # applying the function
f_steal = f_steal.drop(columns="geometry")  # deleting the old copy
f_steal
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/geopandas/geodataframe.py:1525: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#       OBJECTID                                               geom
# 0            1  MULTIPOLYGON (((149.83550672274902 -36.6830293...
# 1            2  MULTIPOLYGON (((149.8396271447323 -36.67258107...
# 2            3  MULTIPOLYGON (((150.06840930568075 -36.4304321...
# 3            4  MULTIPOLYGON (((146.94309422956897 -36.0601199...
# 4            5  MULTIPOLYGON (((146.9541924983418 -36.05697090...
# ...        ...                                                ...
# 2341      2342  MULTIPOLYGON (((153.5392522949455 -28.18898614...
# 2342      2343  MULTIPOLYGON (((153.52414424229008 -28.1839644...
# 2343      2344  MULTIPOLYGON (((153.53260003012065 -28.1812418...
# 2344      2345  MULTIPOLYGON (((153.52522073463135 -28.1775943...
# 2345      2346  MULTIPOLYGON (((153.5443778605224 -28.16796689...
#
# [2346 rows x 2 columns]

# %%
f_steal = f_steal.rename(columns = {'OBJECTID' : 'object_id'})

# %%
conn.execute(text("""
 drop table if exists steal CASCADE;
 create table steal(
     object_id integer PRIMARY KEY,
     geom GEOMETRY(MULTIPOLYGON,7844)
);"""))

f_steal.to_sql('steal', conn, if_exists='append', index = False, 
                   dtype={'geom': Geometry('MULTIPOLYGON', GDA2020)})
query(conn, "select * from steal")
# Out:
#       object_id                                               geom
# 0             1  0106000020A41E00000100000001030000000100000008...
# 1             2  0106000020A41E00000100000001030000000100000023...
# 2             3  0106000020A41E0000010000000103000000010000001B...
# 3             4  0106000020A41E00000100000001030000000100000018...
# 4             5  0106000020A41E0000010000000103000000010000000A...
# ...         ...                                                ...
# 2341       2342  0106000020A41E00000100000001030000000100000024...
# 2342       2343  0106000020A41E00000100000001030000000100000020...
# 2343       2344  0106000020A41E0000010000000103000000010000001B...
# 2344       2345  0106000020A41E00000100000001030000000100000007...
# 2345       2346  0106000020A41E0000010000000103000000010000003D...
#
# [2346 rows x 2 columns]

# %% [markdown]
# ## Merge these datasets

# %%
conn.execute(text("""DROP VIEW IF EXISTS ambulance_per_1000_people;
CREATE VIEW ambulance_per_1000_people AS
SELECT sa2.sa2_code, ROUND(COUNT(a.properties) * 1000.0 / COALESCE(population.total_people, 1)) 
AS ambulance_per_1000_people
FROM sa2
LEFT JOIN ambulance a ON ST_Contains(sa2.geom, a.geom)
JOIN population ON sa2.sa2_code = population.sa2_code
where population.total_people > 0
GROUP BY sa2.sa2_code, population.total_people;
"""))

# %%
query(conn, """select * from ambulance_per_1000_people""")
# Out:
#       sa2_code  ambulance_per_1000_people
# 0    102011028                        0.0
# 1    102011029                        0.0
# 2    102011030                        0.0
# 3    102011031                        0.0
# 4    102011032                        0.0
# ..         ...                        ...
# 367  128021537                        0.0
# 368  128021538                        0.0
# 369  128021607                        0.0
# 370  128021608                        0.0
# 371  128021609                        0.0
#
# [372 rows x 2 columns]

# %%
conn.execute(text("""DROP VIEW IF EXISTS steal_per_1000_people CASCADE;
    CREATE VIEW steal_per_1000_people AS
SELECT sa2.sa2_code, COUNT(steal.object_id) * 1000.0 / COALESCE(population.total_people, 1) AS steal_per_1000_people
FROM sa2
LEFT JOIN steal ON ST_Contains(sa2.geom, steal.geom)
JOIN population ON sa2.sa2_code = population.sa2_code
where population.total_people > 0
GROUP BY sa2.sa2_code, population.total_people;"""))

# %%
query(conn, "select * from steal_per_1000_people")
# Out:
#       sa2_code  steal_per_1000_people
# 0    102011028               0.000000
# 1    102011029               0.000000
# 2    102011030               0.000000
# 3    102011031               0.135108
# 4    102011032               0.281083
# ..         ...                    ...
# 367  128021537               0.000000
# 368  128021538               0.256750
# 369  128021607               0.287704
# 370  128021608               0.000000
# 371  128021609               0.000000
#
# [372 rows x 2 columns]

# %%
conn.execute(text("""DROP VIEW IF EXISTS parcel_sum cascade;
CREATE VIEW parcel_sum AS
SELECT sa2.sa2_code, sum(parcel.parcel_count)/ ST_Area(sa2.geom) / 1000000.0 as parcel_sum
FROM sa2
LEFT JOIN parcel ON sa2.sa2_code =parcel.sa2_code
GROUP BY sa2.sa2_code,sa2.geom;
"""))
query(conn, "select * from parcel_sum where parcel_sum is not NULL")
# Out:
#       sa2_code  parcel_sum
# 0    117011321    6.856538
# 1    125011587    7.472179
# 2    120011385   12.481695
# 3    123011433    1.773265
# 4    124011453    1.371638
# ..         ...         ...
# 255  116011304    9.100750
# 256  125011583    5.537905
# 257  124031461    6.449772
# 258  115041301    0.564318
# 259  121031407    4.793201
#
# [260 rows x 2 columns]

# %%
conn.execute(text("""
DROP VIEW IF EXISTS sa2_new_metrics CASCADE;
CREATE VIEW sa2_new_metrics AS
Select sa2_metrics.*, parcel_sum.parcel_sum, 
    COALESCE(ambulance_per_1000_people.ambulance_per_1000_people, 0) AS ambulance_per_1000_people,
    COALESCE(steal_per_1000_people.steal_per_1000_people, 0) AS steal_per_1000_people
    from sa2_metrics
    Left Join parcel_sum on sa2_metrics.sa2_code = parcel_sum.sa2_code
    Left Join ambulance_per_1000_people on sa2_metrics.sa2_code= ambulance_per_1000_people.sa2_code
    Left Join steal_per_1000_people on steal_per_1000_people.sa2_code = sa2_metrics.sa2_code
"""))

# %%
query(conn, "select * from sa2_new_metrics")
# Out:
#       sa2_code                     sa2_name  \
# 0    102011028     Avoca Beach - Copacabana
# 1    102011029  Box Head - MacMasters Beach
# 2    102011030              Calga - Kulnura
# 3    102011031          Erina - Green Point
# 4    102011032        Gosford - Springfield
# ..         ...                          ...
# 355  128021536  Oyster Bay - Como - Jannali
# 356  128021538        Sutherland - Kirrawee
# 357  128021607                     Engadine
# 358  128021608         Loftus - Yarrawarrah
# 359  128021609             Woronora Heights
#
#                                                   geom  businesses_per_1000  \
# 0    0106000020A41E0000010000000103000000010000005E...            83.001328
# 1    0106000020A41E00000100000001030000000100000010...            70.484980
# 2    0106000020A41E00000200000001030000000100000085...           198.188711
# 3    0106000020A41E00000100000001030000000100000041...            95.926501
# 4    0106000020A41E0000010000000103000000010000007E...            85.261876
# ..                                                 ...                  ...
# 355  0106000020A41E000001000000010300000001000000EF...            55.392533
# 356  0106000020A41E00000100000001030000000100000089...            70.477984
# 357  0106000020A41E0000010000000103000000010000008E...            49.542551
# 358  0106000020A41E000001000000010300000001000000A1...            50.176775
# 359  0106000020A41E000001000000010300000001000000F0...            54.632498
#
#      stops_per_sqkm  polls_per_sqkm  schools_per_1000_young  parcel_sum  \
# 0      2.033888e+11    3.202973e+09                0.000000    5.273694
# 1      6.906529e+10    6.424678e+08                0.000000    1.740767
# 2      2.312523e+09    9.411432e+07                1.040583    0.057396
# 3      8.699448e+10    1.831463e+09                0.000000    1.416636
# 4      2.165257e+11    4.269521e+09                0.000000    3.486979
# ..              ...             ...                     ...         ...
# 355    2.922204e+11    8.053318e+09                0.000000    8.063672
# 356    2.575748e+11    7.925380e+09                0.393856    5.563617
# 357    2.527737e+11    8.006408e+09                0.000000    5.860691
# 358    3.836843e+11    5.328948e+09                0.000000    6.309475
# 359    1.371302e+11    3.265004e+09                0.000000    3.999630
#
#      ambulance_per_1000_people  steal_per_1000_people
# 0                          0.0               0.000000
# 1                          0.0               0.000000
# 2                          0.0               0.000000
# 3                          0.0               0.135108
# 4                          0.0               0.281083
# ..                         ...                    ...
# 355                        0.0               0.135434
# 356                        0.0               0.256750
# 357                        0.0               0.287704
# 358                        0.0               0.000000
# 359                        0.0               0.000000
#
# [360 rows x 10 columns]

# %%
gdf_3 = gpd.read_postgis("""select * from sa2_new_metrics""", conn, crs=7844)

# %%
gdf_3.head()
# Out:
#     sa2_code                     sa2_name  \
# 0  102011028     Avoca Beach - Copacabana
# 1  102011029  Box Head - MacMasters Beach
# 2  102011030              Calga - Kulnura
# 3  102011031          Erina - Green Point
# 4  102011032        Gosford - Springfield
#
#                                                 geom  businesses_per_1000  \
# 0  MULTIPOLYGON (((151.41373 -33.46558, 151.41362...            83.001328
# 1  MULTIPOLYGON (((151.37484 -33.50052, 151.37507...            70.484980
# 2  MULTIPOLYGON (((151.20449 -33.53280, 151.20448...           198.188711
# 3  MULTIPOLYGON (((151.37194 -33.43698, 151.37288...            95.926501
# 4  MULTIPOLYGON (((151.32349 -33.42779, 151.32342...            85.261876
#
#    stops_per_sqkm  polls_per_sqkm  schools_per_1000_young  parcel_sum  \
# 0    2.033888e+11    3.202973e+09                0.000000    5.273694
# 1    6.906529e+10    6.424678e+08                0.000000    1.740767
# 2    2.312523e+09    9.411432e+07                1.040583    0.057396
# 3    8.699448e+10    1.831463e+09                0.000000    1.416636
# 4    2.165257e+11    4.269521e+09                0.000000    3.486979
#
#    ambulance_per_1000_people  steal_per_1000_people
# 0                        0.0               0.000000
# 1                        0.0               0.000000
# 2                        0.0               0.000000
# 3                        0.0               0.135108
# 4                        0.0               0.281083

# %%
# Impute NaN values with the median
gdf_3['parcel_sum'].fillna(gdf_3['parcel_sum'].median(), inplace=True)

# %%
gdf_3.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   sa2_code                   360 non-null    int64
#  1   sa2_name                   360 non-null    object
#  2   geom                       360 non-null    geometry
#  3   businesses_per_1000        360 non-null    float64
#  4   stops_per_sqkm             360 non-null    float64
#  5   polls_per_sqkm             360 non-null    float64
#  6   schools_per_1000_young     360 non-null    float64
#  7   parcel_sum                 360 non-null    float64
#  8   ambulance_per_1000_people  360 non-null    float64
#  9   steal_per_1000_people      360 non-null    float64
# dtypes: float64(7), geometry(1), int64(1), object(1)
# memory usage: 28.3+ KB

# %%
from scipy.stats import zscore
from scipy.special import expit
# Calculate z-scores
gdf_3['ambulance_per_1000_people_z'] = zscore(gdf_3['ambulance_per_1000_people'])
gdf_3['parcel_sum_z'] = zscore(gdf_3['parcel_sum'])
gdf_3['businesses_per_1000_z'] = zscore(gdf_3['businesses_per_1000'])
gdf_3['stops_per_sqkm_z'] = zscore(gdf_3['stops_per_sqkm'])
gdf_3['polls_per_sqkm_z'] = zscore(gdf_3['polls_per_sqkm'])
gdf_3['schools_per_1000_young_z'] = zscore(gdf_3['schools_per_1000_young'])
gdf_3['steal_per_1000_people_z'] = zscore(gdf_3['steal_per_1000_people'])

# Calculate the final bustling score using the sigmoid function
gdf_3['final_bustling_score'] = expit(gdf_3['businesses_per_1000_z'] + gdf_3['stops_per_sqkm_z'] + 
                                      gdf_3['polls_per_sqkm_z'] + gdf_3['schools_per_1000_young_z'] 
                                       + gdf_3['parcel_sum_z'] + gdf_3['steal_per_1000_people_z'] +
                                     gdf_3['ambulance_per_1000_people_z'])

# %%
gdf_3
# Out:
#       sa2_code                     sa2_name  \
# 0    102011028     Avoca Beach - Copacabana
# 1    102011029  Box Head - MacMasters Beach
# 2    102011030              Calga - Kulnura
# 3    102011031          Erina - Green Point
# 4    102011032        Gosford - Springfield
# ..         ...                          ...
# 355  128021536  Oyster Bay - Como - Jannali
# 356  128021538        Sutherland - Kirrawee
# 357  128021607                     Engadine
# 358  128021608         Loftus - Yarrawarrah
# 359  128021609             Woronora Heights
#
#                                                   geom  businesses_per_1000  \
# 0    MULTIPOLYGON (((151.41373 -33.46558, 151.41362...            83.001328
# 1    MULTIPOLYGON (((151.37484 -33.50052, 151.37507...            70.484980
# 2    MULTIPOLYGON (((151.20449 -33.53280, 151.20448...           198.188711
# 3    MULTIPOLYGON (((151.37194 -33.43698, 151.37288...            95.926501
# 4    MULTIPOLYGON (((151.32349 -33.42779, 151.32342...            85.261876
# ..                                                 ...                  ...
# 355  MULTIPOLYGON (((151.07861 -33.99748, 151.07861...            55.392533
# 356  MULTIPOLYGON (((151.05006 -34.02158, 151.05008...            70.477984
# 357  MULTIPOLYGON (((150.99568 -34.05361, 150.99570...            49.542551
# 358  MULTIPOLYGON (((151.03955 -34.04175, 151.03954...            50.176775
# 359  MULTIPOLYGON (((151.01852 -34.03119, 151.01862...            54.632498
#
#      stops_per_sqkm  polls_per_sqkm  schools_per_1000_young  parcel_sum  \
# 0      2.033888e+11    3.202973e+09                0.000000    5.273694
# 1      6.906529e+10    6.424678e+08                0.000000    1.740767
# 2      2.312523e+09    9.411432e+07                1.040583    0.057396
# 3      8.699448e+10    1.831463e+09                0.000000    1.416636
# 4      2.165257e+11    4.269521e+09                0.000000    3.486979
# ..              ...             ...                     ...         ...
# 355    2.922204e+11    8.053318e+09                0.000000    8.063672
# 356    2.575748e+11    7.925380e+09                0.393856    5.563617
# 357    2.527737e+11    8.006408e+09                0.000000    5.860691
# 358    3.836843e+11    5.328948e+09                0.000000    6.309475
# 359    1.371302e+11    3.265004e+09                0.000000    3.999630
#
#      ambulance_per_1000_people  steal_per_1000_people  \
# 0                          0.0               0.000000
# 1                          0.0               0.000000
# 2                          0.0               0.000000
# 3                          0.0               0.135108
# 4                          0.0               0.281083
# ..                         ...                    ...
# 355                        0.0               0.135434
# 356                        0.0               0.256750
# 357                        0.0               0.287704
# 358                        0.0               0.000000
# 359                        0.0               0.000000
#
#      ambulance_per_1000_people_z  parcel_sum_z  businesses_per_1000_z  \
# 0                            NaN     -0.366095              -0.066874
# 1                            NaN     -1.406614              -0.135036
# 2                            NaN     -1.902401               0.560419
# 3                            NaN     -1.502077               0.003515
# 4                            NaN     -0.892319              -0.054563
# ..                           ...           ...                    ...
# 355                          NaN      0.455610              -0.217227
# 356                          NaN     -0.280707              -0.135074
# 357                          NaN     -0.193213              -0.249085
# 358                          NaN     -0.061037              -0.245631
# 359                          NaN     -0.741333              -0.221366
#
#      stops_per_sqkm_z  polls_per_sqkm_z  schools_per_1000_young_z  \
# 0           -0.443428         -0.355345                 -0.160365
# 1           -1.343727         -0.486405                 -0.160365
# 2           -1.791135         -0.514472                 13.836651
# 3           -1.223557         -0.425546                 -0.160365
# 4           -0.355378         -0.300753                 -0.160365
# ..                ...               ...                       ...
# 355          0.151963         -0.107079                 -0.160365
# 356         -0.080248         -0.113627                  5.137442
# 357         -0.112427         -0.109480                 -0.160365
# 358          0.764997         -0.246526                 -0.160365
# 359         -0.887524         -0.352170                 -0.160365
#
#      steal_per_1000_people_z  final_bustling_score
# 0                  -0.799941                   NaN
# 1                  -0.799941                   NaN
# 2                  -0.799941                   NaN
# 3                   0.041565                   NaN
# 4                   0.950760                   NaN
# ..                       ...                   ...
# 355                 0.043598                   NaN
# 356                 0.799206                   NaN
# 357                 0.991994                   NaN
# 358                -0.799941                   NaN
# 359                -0.799941                   NaN
#
# [360 rows x 18 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
gdf_3.plot(column='final_bustling_score', ax=ax, legend=True, cmap='viridis')
ax.set_title('Final Bustling Score')
plt.savefig('final_bustling_score')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot the final bustling score on a map
gdf_3.plot(column='final_bustling_score', ax=ax1, legend=True, cmap='viridis')
ax1.set_title('Final Bustling Score with new datasets')

# Plot the median income on a map
gdf_income.plot(column='median_income', ax=ax2, legend=True, cmap='plasma')
ax2.set_title('Median Income')
plt.savefig('bustling_score_vs_income')
plt.tight_layout()
plt.show()

# %%
corr, p_value = pearsonr(gdf['final_bustling_score'], gdf_income['median_income'])
print(f"Pearson correlation coefficient: {corr:.4f}")
print(f"p-value: {p_value:.4f}")
# Out:
# Pearson correlation coefficient: 0.0747
# p-value: 0.1575

# %% [markdown]
# # Task 4: Creating a Rank-based Score and the Machine Learning Model

# %%
gdf_2 = gpd.read_postgis("""select * from sa2_metrics""", conn, crs=7844)

# %%
import pandas as pd
import numpy as np
from scipy.special import erfinv

def rankit(x):
    n = len(x)
    ranks = x.rank(method='dense', ascending=True).values
    return (ranks - 0.5) / (n + 0.25)

def tanh_transform(x):
    return np.tanh(x)

# %%
# Rank the variables
gdf_2['businesses_per_1000_rank'] = gdf_2['businesses_per_1000'].rank(method='dense', ascending=False)
gdf_2['stops_per_sqkm_rank'] = gdf_2['stops_per_sqkm'].rank(method='dense', ascending=False)
gdf_2['polls_per_sqkm_rank'] = gdf_2['polls_per_sqkm'].rank(method='dense', ascending=False)
gdf_2['schools_per_1000_young_rank'] = gdf_2['schools_per_1000_young'].rank(method='dense', ascending=False)

# List of columns to drop
columns_to_drop = ['businesses_per_1000', 'stops_per_sqkm', 'polls_per_sqkm', 'schools_per_1000_young']

# Drop the columns
gdf_2.drop(columns=columns_to_drop, inplace=True)

# Standardize the ranks using the rankit function
gdf_2['businesses_rankit'] = rankit(gdf_2['businesses_per_1000_rank'])
gdf_2['stops_rankit'] = rankit(gdf_2['stops_per_sqkm_rank'])
gdf_2['polls_rankit'] = rankit(gdf_2['polls_per_sqkm_rank'])
gdf_2['schools_rankit'] = rankit(gdf_2['schools_per_1000_young_rank'])

# %%
# Calculate the rank-based bustling score using the tanh function
gdf_2['rank_based_bustling_score'] = (tanh_transform((gdf_2['businesses_rankit'] + gdf_2['stops_rankit'] + gdf_2['polls_rankit'] + gdf_2['schools_rankit'])/4)+1)/2

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot the final bustling score on a map
gdf_2.plot(column='rank_based_bustling_score', ax=ax1, legend=True, cmap='viridis')
ax1.set_title('Final Rank-Based Bustling Score')

# Plot the median income on a map
gdf.plot(column='final_bustling_score', ax=ax2, legend=True, cmap='plasma')
ax2.set_title('Final Bustling Score')


plt.tight_layout()
plt.savefig("final_score.jpg")
plt.show()

# %%
from sklearn.metrics.pairwise import cosine_similarity

def compare_scores(old_score, new_score):
    # Calculate correlation coefficient
    corr, p_value = pearsonr(gdf['final_bustling_score'], gdf_2['rank_based_bustling_score'])
    
    # Calculate cosine similarity
    # Reshape the arrays to be column vectors for cosine similarity calculation
    old_score = np.array(old_score).reshape(-1, 1)
    new_score = np.array(new_score).reshape(-1, 1)
    cosine_sim = cosine_similarity(old_score, new_score)[0, 0]

    return corr, p_value, cosine_sim

# %%
old_score = gdf['final_bustling_score']
new_score = gdf_2['rank_based_bustling_score']

correlation, p , cosine_sim = compare_scores(old_score, new_score)
print("Correlation Coefficient:", correlation)
print("Cosine Similarity:", cosine_sim)
# Out:
# Correlation Coefficient: -0.8357598799817902
# Cosine Similarity: 1.0

# %% [markdown]
# The similarity between the 'final_bustling_score' and the 'rank_based_bustling_score' can be evaluated using two distinct metrics. The correlation coefficient provides insight into the strength and direction of their linear relationship. In this case, the correlation coefficient value of -0.822 suggests a strong positive linear relationship between the two scores. Additionally, the cosine similarity measure offers a perspective on their directional similarity in multi-dimensional space. With a cosine similarity value of 1.0, it indicates a perfect alignment between the two scores, implying that they are highly similar in their directional trends. These results collectively suggest a significant and consistent similarity between the original 'final_bustling_score' and the newly derived 'rank_based_bustling_score', providing confidence in the coherence of their underlying patterns and trends.

# %%
import pandas as pd
import geopandas as gpd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
gdf_3 = gpd.read_postgis("""select * from sa2_metrics""", conn, crs=7844)

# %%
gdf_3.head()
# Out:
#     sa2_code                     sa2_name  \
# 0  102011028     Avoca Beach - Copacabana
# 1  102011029  Box Head - MacMasters Beach
# 2  102011030              Calga - Kulnura
# 3  102011031          Erina - Green Point
# 4  102011032        Gosford - Springfield
#
#                                                 geom  businesses_per_1000  \
# 0  MULTIPOLYGON (((151.41373 -33.46558, 151.41362...            83.001328
# 1  MULTIPOLYGON (((151.37484 -33.50052, 151.37507...            70.484980
# 2  MULTIPOLYGON (((151.20449 -33.53280, 151.20448...           198.188711
# 3  MULTIPOLYGON (((151.37194 -33.43698, 151.37288...            95.926501
# 4  MULTIPOLYGON (((151.32349 -33.42779, 151.32342...            85.261876
#
#    stops_per_sqkm  polls_per_sqkm  schools_per_1000_young
# 0    2.033888e+11    3.202973e+09                0.000000
# 1    6.906529e+10    6.424678e+08                0.000000
# 2    2.312523e+09    9.411432e+07                1.040583
# 3    8.699448e+10    1.831463e+09                0.000000
# 4    2.165257e+11    4.269521e+09                0.000000

# %%
# Feature selection
features = ['businesses_per_1000', 'stops_per_sqkm', 'polls_per_sqkm', 'schools_per_1000_young']

# Standardize the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_scaled = scaler.fit_transform(gdf_3[features])

# %%
# Apply K-means clustering
kmeans = KMeans(n_clusters=5, random_state=42)
gdf_3['cluster'] = kmeans.fit_predict(data_scaled)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
gdf_3.head(10)
# Out:
#     sa2_code                     sa2_name  \
# 0  102011028     Avoca Beach - Copacabana
# 1  102011029  Box Head - MacMasters Beach
# 2  102011030              Calga - Kulnura
# 3  102011031          Erina - Green Point
# 4  102011032        Gosford - Springfield
# 5  102011033                      Kariong
# 6  102011034  Kincumber - Picketts Valley
# 7  102011035                       Narara
# 8  102011036       Niagara Park - Lisarow
# 9  102011037      Point Clare - Koolewong
#
#                                                 geom  businesses_per_1000  \
# 0  MULTIPOLYGON (((151.41373 -33.46558, 151.41362...            83.001328
# 1  MULTIPOLYGON (((151.37484 -33.50052, 151.37507...            70.484980
# 2  MULTIPOLYGON (((151.20449 -33.53280, 151.20448...           198.188711
# 3  MULTIPOLYGON (((151.37194 -33.43698, 151.37288...            95.926501
# 4  MULTIPOLYGON (((151.32349 -33.42779, 151.32342...            85.261876
# 5  MULTIPOLYGON (((151.28570 -33.43234, 151.28592...            41.884014
# 6  MULTIPOLYGON (((151.37293 -33.46728, 151.37267...            62.008390
# 7  MULTIPOLYGON (((151.32173 -33.39424, 151.32215...            36.156306
# 8  MULTIPOLYGON (((151.34439 -33.38197, 151.34385...            46.376108
# 9  MULTIPOLYGON (((151.30846 -33.44284, 151.30825...            46.844106
#
#    stops_per_sqkm  polls_per_sqkm  schools_per_1000_young  cluster
# 0    2.033888e+11    3.202973e+09                0.000000        1
# 1    6.906529e+10    6.424678e+08                0.000000        1
# 2    2.312523e+09    9.411432e+07                1.040583        4
# 3    8.699448e+10    1.831463e+09                0.000000        1
# 4    2.165257e+11    4.269521e+09                0.000000        1
# 5    8.070545e+10    2.483244e+09                0.000000        1
# 6    1.231867e+11    3.519621e+09                0.000000        1
# 7    1.393263e+11    1.339676e+09                0.000000        1
# 8    6.353134e+10    6.168091e+08                0.000000        1
# 9    2.159951e+11    3.042185e+09                0.000000        1

# %% [markdown]
# ### Greater Sydney Area District Clustering
#
# The districts in the Greater Sydney area have been classified into 5 distinct clusters based on various urban features. These features include the number of businesses per 1,000 residents, transportation stops per square kilometer, polling places per square kilometer, and schools per 1,000 young population. Below is a detailed breakdown of each cluster:
#
# #### Cluster 0 (Purple)
# - **Characteristics**: Concentrated around the central business district of Sydney.
# - **Features**:
#   - High density of businesses.
#   - Numerous public transport stops.
#   - Many polling places.
#   - Fewer schools per young population compared to other clusters.
#
# #### Cluster 1 (Dark Blue)
# - **Characteristics**: Represents suburban and residential areas surrounding the city center.
# - **Features**:
#   - Moderate density of businesses.
#   - Adequate transport stops.
#   - Sufficient schools catering to the young population.
#
# #### Cluster 2 (Light Blue)
# - **Characteristics**: Contains only one district, which is an outlier.
# - **Features**:
#   - Extremely high number of businesses per 1,000 residents.
#   - Significantly different from other clusters in terms of commercial density.
#
# #### Cluster 3 (Green)
# - **Characteristics**: Includes districts located further from the city center, likely representing outer suburban or semi-rural areas.
# - **Features**:
#   - Lower density of businesses, transport stops, and schools compared to inner suburbs.
#
# #### Cluster 4 (Yellow)
# - **Characteristics**: Comprises a few districts scattered across the region.
# - **Features**:
#   - Balanced mix of businesses, transport infrastructure, and schools for the young population.
#   - Includes both residential and commercial areas.
#
# This classification helps in understanding the spatial distribution of infrastructural and commercial facilities across the Greater Sydney area, aiding in urban planning and resource allocation.

# %%
gdf_3.plot(column=gdf_3['cluster'], legend=True)
plt.savefig('fig.jpg')
plt.show()

# %%
# conn.close()
# db.dispose()
